# %% [markdown]
# <a href="https://colab.research.google.com/github/cnukaus/learner/blob/master/Lecture_2_CRoss_Industry_Standard_Process_for_Data_Mining.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# <img height="45px" src="https://colab.research.google.com/img/colab_favicon.ico" align="left" hspace="10px" vspace="0px">
#
# <h1>CRISP-DM Methodology</h1>

# %% [markdown]
# # Prepare Environment
#
# Upload your data tip:
# Run git command in Colab: https://medium.com/@yuraist/how-to-upload-your-own-dataset-into-google-colab-e228727c87e9

# %% [markdown]
# # Explore!

# %% [markdown]
# ## Getting Started
#
# There is a **code cell** with a short Python script that computes a value, stores it in a variable, and prints the result:
# According to PEP8 naming convention

# %%
# Python libraries
import math
import re
import datetime


# Handle table-like data and matrices
import numpy as np
import pandas as pd

# Visualisation
import matplotlib as mpl
import matplotlib.pyplot as plt
import matplotlib.pylab as pylab
import seaborn as sns

# Configure visualisations
# %matplotlib inline   

# https://stackoverflow.com/questions/43027980/purpose-of-matplotlib-inline#answer-43028034
mpl.style.use( 'ggplot' )
sns.set_style( 'white' )
pylab.rcParams[ 'figure.figsize' ] = 15 , 10

# %%
def plot_distribution0( df , var , target , **kwargs ):
    row = kwargs.get( 'row' , None )
    col = kwargs.get( 'col' , None )
    facet = sns.FacetGrid( df , hue=target , aspect=4 , row = row , col = col )
    facet.map( sns.kdeplot , var , shade= True )
    facet.set(xlim= (0 , df[ var ].max() ) )
    facet.add_legend()
def plot_distribution( df , var , target , **kwargs ):
    row = kwargs.get( 'row' , None )
    col = kwargs.get( 'col' , None )
    facet = sns.FacetGrid( df , hue=target , aspect=4 , row = row , col = col )
    facet.map( sns.kdeplot , var , shade= True )
    facet.set( xlim=( 1940  , df[ var ].max() ) )
    facet.add_legend()
def plot_categories( df , cat , target , **kwargs ):
    row = kwargs.get( 'row' , None )
    col = kwargs.get( 'col' , None )
    facet = sns.FacetGrid( df , row = row , col = col )
    facet.map( sns.barplot , cat , target )
    facet.add_legend()

def plot_correlation_map( df ):
    corr = df.corr()
    _ , ax = plt.subplots( figsize =( 12 , 10 ) )
    cmap = sns.diverging_palette( 220 , 10 , as_cmap = True )
    _ = sns.heatmap(
        corr, 
        cmap = cmap,
        square=True, 
        cbar_kws={ 'shrink' : .9 }, 
        ax=ax, 
        annot = True, 
        annot_kws = { 'fontsize' : 12 }
    )
# https://www.kaggle.com/helgejo/an-interactive-data-science-tutorial

def histograms( df , variables , n_rows , n_cols ):
    fig = plt.figure( figsize = ( 16 , 12 ) )
    for i, var_name in enumerate( variables ):
        ax=fig.add_subplot( n_rows , n_cols , i+1 )
        df[ var_name ].hist( bins=10 , ax=ax )
        ax.set_title( 'Skew: ' + str( round( float( df[ var_name ].skew() ) , ) ) ) # + ' ' + var_name ) #var_name+" Distribution")
        ax.set_xticklabels( [] , visible=False )
        ax.set_yticklabels( [] , visible=False )
    fig.tight_layout()  # Improves appearance a bit.
    plt.show()

def distribution( df , var , target , **kwargs ):
    row = kwargs.get( 'row' , None )
    col = kwargs.get( 'col' , None )
    facet = sns.FacetGrid( df , hue=target , aspect=4 , row = row , col = col )
    facet.map( sns.kdeplot , var , shade= True )
    facet.set( xlim=( df[ var ].min() , df[ var ].max() ) )
    facet.add_legend()

def categories( df , cat , target , **kwargs ):
    row = kwargs.get( 'row' , None )
    col = kwargs.get( 'col' , None )
    facet = sns.FacetGrid( df , row = row , col = col )
    facet.map( sns.barplot , cat , target )
    facet.add_legend()

def correlation_map( df ):
    corr = df.corr()
    _ , ax = plt.subplots( figsize =( 12 , 10 ) )
    cmap = sns.diverging_palette( 220 , 10 , as_cmap = True )
    _ = sns.heatmap(
        corr, 
        cmap = cmap,
        square=True, 
        cbar_kws={ 'shrink' : .9 }, 
        ax=ax, 
        annot = True, 
        annot_kws = { 'fontsize' : 12 }
    )

def describe_more( df ):
    var = [] ; l = [] ; t = []
    for x in df:
        var.append( x )
        l.append( len( pd.value_counts( df[ x ] ) ) )
        t.append( df[ x ].dtypes )
    levels = pd.DataFrame( { 'Variable' : var , 'Levels' : l , 'Datatype' : t } )
    levels.sort_values( by = 'Levels' , inplace = True )
    return levels

def variable_importance( X , y ):
    tree = DecisionTreeClassifier( random_state = 99 )
    tree.fit( X , y )
    plot_model_var_imp( tree , X , y )
    
def model_var_imp( model , X , y ):
    imp = pd.DataFrame( 
        model.feature_importances_  , 
        columns = [ 'Importance' ] , 
        index = X.columns 
    )
    imp = imp.sort_values( [ 'Importance' ] , ascending = True )
    imp[ : 10 ].plot( kind = 'barh' )
    print (model.score( X , y ))
    
def category_values(dataframe, categories):
    for c in categories:
        print('\n', dataframe.groupby(by=c)[c].count().sort_values(ascending=False))
        print('Nulls: ', dataframe[c].isnull().sum())

# %% [markdown]
# ### Data Loading

# %%
# !git clone https://github.com/cnukaus/learner.git
# !ls
# Out:
# Cloning into 'learner'...
# remote: Enumerating objects: 4, done.
# remote: Counting objects: 100% (4/4), done.
# remote: Compressing objects: 100% (3/3), done.
# remote: Total 135 (delta 0), reused 0 (delta 0), pack-reused 131
# Receiving objects: 100% (135/135), 4.37 MiB | 8.68 MiB/s, done.
# Resolving deltas: 100% (60/60), done.
# learner  sample_data

# %% [markdown]
# ### Get field type information

# %%
  
df = pd.read_csv('learner/lecture02/L2-AviationData.csv', sep=',', header=0, encoding = 'iso-8859-1')

df.sample(10)
df.info
# Out:
# <bound method DataFrame.info of              Event.Id Investigation.Type Accident.Number  Event.Date  \
# 0      20181217X10943           Accident      GAA19CA098  2018-12-16
# 1      20181217X25746           Accident      GAA19CA097  2018-12-15
# 2      20181213X41114           Accident      ERA19LA065  2018-12-13
# 3      20181213X45528           Accident      CEN19FA044  2018-12-13
# 4      20181214X90303           Accident      GAA19CA096  2018-12-11
# 5      20181210X21905           Accident      GAA19CA091  2018-12-10
# 6      20181208X53536           Accident      GAA19CA090  2018-12-08
# 7      20181206X45049           Accident      GAA19CA088  2018-12-05
# 8      20181204X03049           Accident      GAA19CA086  2018-12-04
# 9      20181212X01623           Accident      ERA19LA063  2018-12-04
# 10     20181204X93009           Accident      GAA19CA087  2018-12-03
# 11     20181204X05247           Accident      WPR19LA035  2018-12-02
# 12     20181201X45922           Accident      ERA19FA060  2018-12-01
# 13     20181130X14057           Accident      ERA19FA059  2018-11-30
# 14     20181130X80724           Accident      CEN19LA039  2018-11-30
# 15     20181130X31617           Accident      CEN19FA036  2018-11-30
# 16     20181130X14309           Accident      WPR19WA033  2018-11-29
# 17     20181129X63138           Accident      GAA19CA080  2018-11-29
# 18     20181129X30228           Accident      ERA19LA057  2018-11-29
# 19     20181129X70430           Accident      CEN19FA035  2018-11-29
# 20     20181206X23959           Accident      WPR19WA038  2018-11-28
# 21     20181128X44044           Accident      GAA19CA085  2018-11-28
# 22     20181129X43605           Accident      GAA19CA083  2018-11-28
# 23     20181128X85901           Accident     GAA19CA079B  2018-11-28
# 24     20181128X85901           Accident     GAA19CA079A  2018-11-28
# 25     20181128X42306           Accident      GAA19CA078  2018-11-28
# 26     20181128X93322           Accident      GAA19CA084  2018-11-27
# 27     20181126X63346           Accident      GAA19CA075  2018-11-26
# 28     20181130X81333           Accident      ERA19WA058  2018-11-26
# 29     20181203X05042           Incident      ENG19WA005  2018-11-26
# ...               ...                ...             ...         ...
# 82605  20020917X02333           Incident      LAX82IA034  1982-01-03
# 82606  20020917X02255           Accident      LAX82FA040  1982-01-03
# 82607  20020917X02155           Accident      LAX82DA035  1982-01-03
# 82608  20020917X01992           Accident      FTW82DA036  1982-01-03
# 82609  20020917X01960           Accident      DEN82DTI09  1982-01-03
# 82610  20020917X01905           Accident      DCA82AA008  1982-01-03
# 82611  20020917X01720           Accident      ATL82FA033  1982-01-03
# 82612  20020917X02481           Accident      NYC82DA016  1982-01-02
# 82613  20020917X02339           Accident      MIA82DA028  1982-01-02
# 82614  20020917X02148           Accident      FTW82FRJ07  1982-01-02
# 82615  20020917X02134           Accident      FTW82FRA14  1982-01-02
# 82616  20020917X02119           Accident      FTW82FPJ10  1982-01-02
# 82617  20020917X02117           Accident      FTW82FPG08  1982-01-02
# 82618  20020917X01962           Accident      DEN82DTM08  1982-01-02
# 82619  20020917X01894           Accident      CHI82FEC08  1982-01-02
# 82620  20020917X01776           Accident      CHI82DA020  1982-01-02
# 82621  20020917X01657           Accident      ATL82DA027  1982-01-02
# 82622  20020917X01656           Accident      ANC82FAG14  1982-01-02
# 82623  20020909X01562           Accident      SEA82DA022  1982-01-01
# 82624  20020909X01561           Accident      NYC82DA015  1982-01-01
# 82625  20020909X01560           Accident      MIA82DA029  1982-01-01
# 82626  20020909X01559           Accident      FTW82DA034  1982-01-01
# 82627  20020909X01558           Accident      ATL82DKJ10  1982-01-01
# 82628  20001218X45446           Accident      CHI81LA106  1981-08-01
# 82629  20170710X52551           Accident      NYC79AA106  1979-09-17
# 82630  20041105X01764           Accident      CHI79FA064  1979-08-02
# 82631  20001218X45448           Accident      LAX96LA321  1977-06-19
# 82632  20061025X01555           Accident      NYC07LA005  1974-08-30
# 82633  20001218X45447           Accident      LAX94LA336  1962-07-19
# 82634  20001218X45444           Accident      SEA87LA080  1948-10-24
#
#                         Location        Country   Latitude   Longitude  \
# 0                 Grangville, ID  United States  45.583611 -115.681667
# 1                   MORIARTY, NM  United States  34.970000 -106.000000
# 2                Punta Gorda, FL  United States  26.925278  -82.001111
# 3                 Valparaiso, IN  United States  41.451667  -87.004444
# 4                   Hartford, WI  United States  43.330278  -88.326111
# 5                    Chester, CT  United States        NaN         NaN
# 6                   Hesperia, CA  United States  34.376945 -117.316111
# 7                   Cornelia, GA  United States        NaN         NaN
# 8                       Reno, NV  United States  39.658889 -119.865833
# 9                     Moscow, PA  United States  41.326945  -75.591111
# 10                    Monroe, NC  United States  35.017500  -80.621945
# 11                Santa Rita, GU  United States        NaN         NaN
# 12           Fort Lauderdale, FL  United States  26.205000  -80.157222
# 13              Apalachicola, FL  United States  29.763611  -85.022500
# 14                     Fargo, ND  United States  46.920556  -96.815833
# 15                   Memphis, IN  United States  38.475278  -85.811111
# 16     Machadodorp, South Africa   South Africa -25.607778   30.514444
# 17                Burlington, WA  United States        NaN         NaN
# 18                  Kennesaw, GA  United States  34.039444  -84.585833
# 19                    Marion, IN  United States  40.480556  -85.682500
# 20      West Bangkala, Indonesia      Indonesia  -5.476389  119.523611
# 21            St. Petersburg, FL  United States        NaN         NaN
# 22                 Rock Hill, SC  United States  34.984722  -81.058056
# 23                      Mesa, AZ  United States  33.307778 -111.655556
# 24                      Mesa, AZ  United States  33.307778 -111.655556
# 25                  Americus, GA  United States  32.039722  -84.294166
# 26               Casa Grande, AZ  United States  32.955000 -111.766945
# 27                 Rio Vista, CA  United States  38.193333 -121.703611
# 28      Jequita?? County, Brazil         Brazil -18.512222  -44.555000
# 29         Addis Ababa, Ethiopia       Ethiopia        NaN         NaN
# ...                          ...            ...        ...         ...
# 82605               VAN NUYS, CA  United States        NaN         NaN
# 82606        10 NM W LEE VIN, CA  United States        NaN         NaN
# 82607         SAN CLEMENTINE, CA  United States        NaN         NaN
# 82608             FORT WORTH, TX  United States        NaN         NaN
# 82609              GREENOUGH, MT  United States        NaN         NaN
# 82610                ASHLAND, VA  United States        NaN         NaN
# 82611              PINEHURST, NC  United States        NaN         NaN
# 82612                GALETON, PA  United States        NaN         NaN
# 82613                  MIAMI, FL  United States        NaN         NaN
# 82614                  HOMER, LA  United States        NaN         NaN
# 82615                 HEARNE, TX  United States        NaN         NaN
# 82616              CHICKASHA, OK  United States        NaN         NaN
# 82617            LITTLE ROCK, AR  United States        NaN         NaN
# 82618                 MIDWAY, UT  United States        NaN         NaN
# 82619              YPSILANTI, MI  United States        NaN         NaN
# 82620              CHARLOTTE, MI  United States        NaN         NaN
# 82621               CHAMBLEE, GA  United States        NaN         NaN
# 82622                SKWENTA, AK  United States        NaN         NaN
# 82623                PULLMAN, WA  United States        NaN         NaN
# 82624           EAST HANOVER, NJ  United States        NaN         NaN
# 82625           JACKSONVILLE, FL  United States        NaN         NaN
# 82626                  HOBBS, NM  United States        NaN         NaN
# 82627               TUSKEGEE, AL  United States        NaN         NaN
# 82628                 COTTON, MN  United States        NaN         NaN
# 82629                 Boston, MA  United States  42.445277  -70.758333
# 82630                 Canton, OH  United States        NaN         NaN
# 82631                 EUREKA, CA  United States        NaN         NaN
# 82632              Saltville, VA  United States  36.922223  -81.878056
# 82633             BRIDGEPORT, CA  United States        NaN         NaN
# 82634            MOOSE CREEK, ID  United States        NaN         NaN
#
#       Airport.Code                    Airport.Name  ...   Purpose.of.Flight  \
# 0              PVT                             NaN  ...         Positioning
# 1              NaN                   MORIARTY MUNI  ...            Personal
# 2              PGD                     Punta Gorda  ...            Personal
# 3              VPZ              Porter County Rgnl  ...            Personal
# 4              HXF                   Hartford Muni  ...            Personal
# 5              SNC                             NaN  ...                 NaN
# 6              L26                        HESPERIA  ...            Personal
# 7              AJR                             NaN  ...       Instructional
# 8              RTS                      RENO/STEAD  ...                 NaN
# 9              NaN                             NaN  ...            Personal
# 10             EQY      CHARLOTTE-MONROE EXECUTIVE  ...            Personal
# 11             NaN                             NaN  ...            Personal
# 12             FXE  Fort Lauderdale Executive Airp  ...            Personal
# 13             AAF           Apalachicola Regional  ...            Personal
# 14             FAR            Hector International  ...            Business
# 15             NaN                             NaN  ...            Business
# 16             NaN                             NaN  ...                 NaN
# 17             BVS                             NaN  ...            Personal
# 18             RYY  Cobb County Intl-Mccollum Fiel  ...            Personal
# 19             MZZ        Marion Municipal Airport  ...            Personal
# 20             NaN                             NaN  ...                 NaN
# 21             SPG                  Albert Whitted  ...                 NaN
# 22             UZA  ROCK HILL/YORK CO/BRYANT FIELD  ...            Personal
# 23             IWA            PHOENIX-MESA GATEWAY  ...       Instructional
# 24             IWA            PHOENIX-MESA GATEWAY  ...                 NaN
# 25             NaN                             NaN  ...  Aerial Application
# 26             CGZ                CASA GRANDE MUNI  ...            Personal
# 27             O88                  Rio Vista Muni  ...            Personal
# 28            SNJI  Fazenda Fortaleza De Santa Air  ...                 NaN
# 29             AAD  Addis Ababa Bole intl. Airport  ...                 NaN
# ...            ...                             ...  ...                 ...
# 82605          VNY                        VAN NUYS  ...            Personal
# 82606          NaN                             NaN  ...            Personal
# 82607          NaN                             NaN  ...            Personal
# 82608          NaN                       OAK GROVE  ...            Personal
# 82609          NaN                             NaN  ...               Ferry
# 82610          NaN                  HANOVER COUNTY  ...            Business
# 82611          SOP                    MOORE COUNTY  ...            Personal
# 82612          5G6                  CHERRY SPRINGS  ...            Personal
# 82613          NaN                             NaN  ...            Personal
# 82614          NaN                             NaN  ...            Personal
# 82615          T72                HEARNE MUNICIPAL  ...            Personal
# 82616          NaN                             NaN  ...            Personal
# 82617          NaN                             NaN  ...            Personal
# 82618          NaN                     FIELD RANCH  ...            Personal
# 82619          YIP                      WILLOW RUN  ...       Instructional
# 82620          49G                      TINKERBELL  ...            Personal
# 82621          PDK                             NaN  ...             Unknown
# 82622          NaN                             NaN  ...            Personal
# 82623          NaN              BLACKBURN AG STRIP  ...            Personal
# 82624          N58                         HANOVER  ...            Business
# 82625          JAX               JACKSONVILLE INTL  ...            Personal
# 82626          NaN                             NaN  ...            Personal
# 82627          NaN                        TUSKEGEE  ...            Personal
# 82628          NaN                             NaN  ...            Personal
# 82629          NaN                             NaN  ...                 NaN
# 82630          NaN                             NaN  ...            Personal
# 82631          NaN                             NaN  ...            Personal
# 82632          NaN                             NaN  ...            Personal
# 82633          NaN                             NaN  ...            Personal
# 82634          NaN                             NaN  ...            Personal
#
#                              Air.Carrier Total.Fatal.Injuries  \
# 0                                    NaN                  NaN
# 1                                    NaN                  NaN
# 2                                    NaN                  NaN
# 3                                    NaN                  1.0
# 4                                    NaN                  NaN
# 5                                    NaN                  NaN
# 6                                    NaN                  NaN
# 7                                    NaN                  NaN
# 8                                    NaN                  NaN
# 9                                    NaN                  NaN
# 10                                   NaN                  NaN
# 11                                   NaN                  NaN
# 12                                   NaN                  2.0
# 13                                   NaN                  1.0
# 14                                   NaN                  NaN
# 15                                   NaN                  3.0
# 16                                   NaN                  NaN
# 17                                   NaN                  NaN
# 18                                   NaN                  NaN
# 19                                   NaN                  1.0
# 20                                   NaN                  NaN
# 21                                   NaN                  NaN
# 22                                   NaN                  NaN
# 23                                   NaN                  NaN
# 24     Daylight Nightlight Ez Flight Llc                  NaN
# 25                                   NaN                  NaN
# 26                                   NaN                  NaN
# 27                                   NaN                  NaN
# 28                                   NaN                  4.0
# 29                                   NaN                  NaN
# ...                                  ...                  ...
# 82605                                NaN                  0.0
# 82606                                NaN                  2.0
# 82607                                NaN                  0.0
# 82608                                NaN                  0.0
# 82609                                NaN                  0.0
# 82610                                NaN                  8.0
# 82611                                NaN                  1.0
# 82612                                NaN                  0.0
# 82613                                NaN                  0.0
# 82614                                NaN                  0.0
# 82615                                NaN                  1.0
# 82616                                NaN                  1.0
# 82617                                NaN                  2.0
# 82618                                NaN                  0.0
# 82619                                NaN                  0.0
# 82620                                NaN                  0.0
# 82621     ROCKY MOUNTAIN HELICOPTERS, IN                  0.0
# 82622                                NaN                  3.0
# 82623                                NaN                  0.0
# 82624                                NaN                  0.0
# 82625                                NaN                  0.0
# 82626                                NaN                  0.0
# 82627                                NaN                  0.0
# 82628                                NaN                  4.0
# 82629                         Air Canada                  NaN
# 82630                                NaN                  1.0
# 82631                                NaN                  2.0
# 82632                                NaN                  3.0
# 82633                                NaN                  4.0
# 82634                                NaN                  2.0
#
#       Total.Serious.Injuries Total.Minor.Injuries Total.Uninjured  \
# 0                        NaN                  NaN             1.0
# 1                        NaN                  NaN             1.0
# 2                        NaN                  1.0             NaN
# 3                        NaN                  NaN             NaN
# 4                        NaN                  NaN             1.0
# 5                        NaN                  NaN             NaN
# 6                        NaN                  NaN             1.0
# 7                        NaN                  NaN             2.0
# 8                        NaN                  NaN             2.0
# 9                        NaN                  NaN             1.0
# 10                       NaN                  NaN             1.0
# 11                       NaN                  2.0             NaN
# 12                       NaN                  1.0             NaN
# 13                       NaN                  NaN             NaN
# 14                       NaN                  9.0             2.0
# 15                       NaN                  NaN             NaN
# 16                       5.0                  NaN             NaN
# 17                       NaN                  NaN             1.0
# 18                       NaN                  2.0             NaN
# 19                       NaN                  NaN             NaN
# 20                       NaN                  NaN             2.0
# 21                       NaN                  NaN             1.0
# 22                       NaN                  NaN             2.0
# 23                       NaN                  NaN             7.0
# 24                       NaN                  NaN             7.0
# 25                       NaN                  NaN             1.0
# 26                       1.0                  NaN             NaN
# 27                       NaN                  NaN             1.0
# 28                       NaN                  NaN             NaN
# 29                       NaN                  NaN             NaN
# ...                      ...                  ...             ...
# 82605                    0.0                  0.0             1.0
# 82606                    1.0                  0.0             0.0
# 82607                    0.0                  2.0             0.0
# 82608                    0.0                  2.0             0.0
# 82609                    0.0                  0.0             1.0
# 82610                    0.0                  0.0             0.0
# 82611                    0.0                  0.0             0.0
# 82612                    0.0                  0.0             1.0
# 82613                    0.0                  0.0             2.0
# 82614                    0.0                  1.0             0.0
# 82615                    0.0                  0.0             0.0
# 82616                    0.0                  0.0             0.0
# 82617                    0.0                  0.0             0.0
# 82618                    0.0                  0.0             1.0
# 82619                    0.0                  0.0             1.0
# 82620                    0.0                  0.0             2.0
# 82621                    0.0                  0.0             1.0
# 82622                    0.0                  0.0             0.0
# 82623                    0.0                  0.0             2.0
# 82624                    0.0                  0.0             2.0
# 82625                    0.0                  3.0             0.0
# 82626                    0.0                  0.0             1.0
# 82627                    0.0                  0.0             1.0
# 82628                    0.0                  0.0             0.0
# 82629                    NaN                  1.0            44.0
# 82630                    2.0                  NaN             NaN
# 82631                    0.0                  0.0             0.0
# 82632                    NaN                  NaN             NaN
# 82633                    0.0                  0.0             0.0
# 82634                    0.0                  0.0             0.0
#
#       Weather.Condition  Broad.Phase.of.Flight   Report.Status  \
# 0                   NaN                    NaN     Preliminary
# 1                   VMC                    NaN     Preliminary
# 2                   VMC               APPROACH     Preliminary
# 3                   VMC                TAKEOFF     Preliminary
# 4                   VMC                    NaN     Preliminary
# 5                   NaN                    NaN     Preliminary
# 6                   VMC                    NaN     Preliminary
# 7                   NaN                    NaN     Preliminary
# 8                   IMC                    NaN     Preliminary
# 9                   VMC                 CRUISE     Preliminary
# 10                  VMC                    NaN     Preliminary
# 11                  VMC                    NaN     Preliminary
# 12                  VMC                TAKEOFF     Preliminary
# 13                  VMC                TAKEOFF     Preliminary
# 14                  IMC                LANDING     Preliminary
# 15                  VMC                TAKEOFF     Preliminary
# 16                  NaN                 CRUISE         Foreign
# 17                  NaN                    NaN     Preliminary
# 18                  VMC                 CRUISE     Preliminary
# 19                  VMC                TAKEOFF     Preliminary
# 20                  NaN                    NaN         Foreign
# 21                  NaN                    NaN     Preliminary
# 22                  VMC                    NaN     Preliminary
# 23                  VMC                    NaN     Preliminary
# 24                  VMC                    NaN     Preliminary
# 25                  VMC                    NaN     Preliminary
# 26                  VMC                    NaN     Preliminary
# 27                  VMC                    NaN     Preliminary
# 28                  NaN              GO-AROUND         Foreign
# 29                  NaN                TAKEOFF         Foreign
# ...                 ...                    ...             ...
# 82605               VMC               APPROACH  Probable Cause
# 82606               IMC                DESCENT  Probable Cause
# 82607               VMC            MANEUVERING  Probable Cause
# 82608               VMC               APPROACH  Probable Cause
# 82609               VMC                TAKEOFF  Probable Cause
# 82610               IMC               APPROACH  Probable Cause
# 82611               IMC               APPROACH  Probable Cause
# 82612               VMC                   TAXI  Probable Cause
# 82613               VMC                 CRUISE  Probable Cause
# 82614               IMC                 CRUISE  Probable Cause
# 82615               IMC                TAKEOFF  Probable Cause
# 82616               IMC                 CRUISE  Probable Cause
# 82617               IMC                 CRUISE  Probable Cause
# 82618               IMC                   TAXI  Probable Cause
# 82619               VMC                TAKEOFF  Probable Cause
# 82620               VMC               APPROACH  Probable Cause
# 82621               VMC               APPROACH  Probable Cause
# 82622               VMC                UNKNOWN  Probable Cause
# 82623               VMC                TAKEOFF  Probable Cause
# 82624               IMC                LANDING  Probable Cause
# 82625               IMC                 CRUISE  Probable Cause
# 82626               VMC               APPROACH  Probable Cause
# 82627               VMC                LANDING  Probable Cause
# 82628               IMC                UNKNOWN  Probable Cause
# 82629               VMC                  CLIMB  Probable Cause
# 82630               VMC               APPROACH  Probable Cause
# 82631               IMC                 CRUISE  Probable Cause
# 82632               IMC                 CRUISE  Probable Cause
# 82633               UNK                UNKNOWN  Probable Cause
# 82634               UNK                 CRUISE  Probable Cause
#
#       Publication.Date
# 0           2018-12-18
# 1           2018-12-20
# 2           2018-12-21
# 3           2018-12-19
# 4           2018-12-18
# 5           2018-12-13
# 6           2018-12-13
# 7           2018-12-13
# 8           2018-12-20
# 9           2018-12-19
# 10          2018-12-07
# 11          2018-12-11
# 12          2018-12-17
# 13          2018-12-11
# 14          2018-12-17
# 15          2018-12-13
# 16                 NaN
# 17          2018-12-13
# 18          2018-12-11
# 19          2018-12-10
# 20                 NaN
# 21          2018-12-04
# 22          2018-12-20
# 23          2018-11-29
# 24          2018-11-29
# 25          2018-12-10
# 26          2018-12-10
# 27          2018-12-11
# 28                 NaN
# 29                 NaN
# ...                ...
# 82605       1983-01-03
# 82606       1983-01-03
# 82607       1983-01-03
# 82608       1983-01-03
# 82609       1983-01-03
# 82610       1983-01-03
# 82611       1983-01-03
# 82612       1983-01-02
# 82613       1983-01-02
# 82614       1983-01-02
# 82615       1983-01-02
# 82616       1983-01-02
# 82617       1983-01-02
# 82618       1983-01-02
# 82619       1983-01-02
# 82620       1983-01-02
# 82621       1983-01-02
# 82622       1983-01-02
# 82623       1982-01-01
# 82624       1982-01-01
# 82625       1982-01-01
# 82626       1982-01-01
# 82627       1982-01-01
# 82628       2001-11-06
# 82629       2017-09-19
# 82630       1980-04-16
# 82631       2000-09-12
# 82632       2007-02-26
# 82633       1996-09-19
# 82634              NaN
#
# [82635 rows x 31 columns]>

# %% [markdown]
# ### Plot first

# %%
plot_correlation_map(df)

# %%
df['Year'] = df['Event.Date'].apply(lambda d: datetime.datetime.strptime(d, "%Y-%m-%d").year)
df['Month'] = df['Event.Date'].apply(lambda d: datetime.datetime.strptime(d, "%Y-%m-%d").month)
df['Day'] = df['Event.Date'].apply(lambda d: datetime.datetime.strptime(d, "%Y-%m-%d").day)

# %% [markdown]
# See what happens

# %%
#df[~df['Country']!='United States'].sample(10)
# splitting date field in the components

df['Year'] = df['Event.Date'].apply(lambda d: datetime.datetime.strptime(d, "%Y-%m-%d").year)
df['Month'] = df['Event.Date'].apply(lambda d: datetime.datetime.strptime(d, "%Y-%m-%d").month)
df['Day'] = df['Event.Date'].apply(lambda d: datetime.datetime.strptime(d, "%Y-%m-%d").day)


df['Country_derive'] = df['Country'].apply(lambda d: d if d=='United States' else 'Foreign')

# %%
describe_more(df)
# Out:
#                   Variable  Levels Datatype
# 1       Investigation.Type       2   object
# 31          Country_derive       2   object
# 16           Amateur.Built       2   object
# 27       Weather.Condition       3   object
# 20                Schedule       3   object
# 11         Aircraft.Damage       3   object
# 29           Report.Status       4   object
# 17       Number.of.Engines       5  float64
# 28   Broad.Phase.of.Flight      12   object
# 33                   Month      12    int64
# 18             Engine.Type      13   object
# 12       Aircraft.Category      13   object
# 19         FAR.Description      18   object
# 21       Purpose.of.Flight      22   object
# 34                     Day      31    int64
# 24  Total.Serious.Injuries      40  float64
# 32                    Year      43    int64
# 25    Total.Minor.Injuries      63  float64
# 23    Total.Fatal.Injuries     124  float64
# 10         Injury.Severity     126   object
# 5                  Country     178   object
# 26         Total.Uninjured     371  float64
# 22             Air.Carrier    2976   object
# 30        Publication.Date    3813   object
# 14                    Make    7894   object
# 8             Airport.Code    9891   object
# 15                   Model   11771   object
# 3               Event.Date   13350   object
# 6                 Latitude   19515  float64
# 7                Longitude   21017  float64
# 9             Airport.Name   23453   object
# 4                 Location   26120   object
# 13     Registration.Number   71407   object
# 0                 Event.Id   81429   object
# 2          Accident.Number   82635   object

# %%
plot_distribution0(df[0:500],var='Year',target='Total.Uninjured',row='Country_derive')
# Out:
# /usr/local/lib/python3.6/dist-packages/statsmodels/nonparametric/kde.py:488: RuntimeWarning: invalid value encountered in true_divide
#   binned = fast_linbin(X, a, b, gridsize) / (delta * nobs)
# /usr/local/lib/python3.6/dist-packages/statsmodels/nonparametric/kdetools.py:34: RuntimeWarning: invalid value encountered in double_scalars
#   FAC1 = 2*(np.pi*bw/RANGE)**2
# /usr/local/lib/python3.6/dist-packages/numpy/core/_methods.py:140: RuntimeWarning: Degrees of freedom <= 0 for slice
#   keepdims=keepdims)
# /usr/local/lib/python3.6/dist-packages/numpy/core/_methods.py:132: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)

# %%
df['Year'].min()
# Out:
# 1948

# %%
#df[df['Year']>1960][0:5000]['Year']
plot_distribution(df[df['Year']>1960][0:3000],var='Year',target='Total.Uninjured',row='Country_derive')
# Out:
# /usr/local/lib/python3.6/dist-packages/numpy/core/_methods.py:140: RuntimeWarning: Degrees of freedom <= 0 for slice
#   keepdims=keepdims)
# /usr/local/lib/python3.6/dist-packages/numpy/core/_methods.py:132: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# /usr/local/lib/python3.6/dist-packages/statsmodels/nonparametric/kde.py:488: RuntimeWarning: invalid value encountered in true_divide
#   binned = fast_linbin(X, a, b, gridsize) / (delta * nobs)
# /usr/local/lib/python3.6/dist-packages/statsmodels/nonparametric/kdetools.py:34: RuntimeWarning: invalid value encountered in double_scalars
#   FAC1 = 2*(np.pi*bw/RANGE)**2

# %%
df.groupby(['Country_derive']).sum()#.reset_index()
# Out:
#                     Latitude     Longitude  Number.of.Engines  \
# Country_derive
# Foreign         2.354950e+04 -1.989426e+04             3180.0
# United States   1.056490e+06 -2.665920e+06            86320.0
#
#                 Total.Fatal.Injuries  Total.Serious.Injuries  \
# Country_derive
# Foreign                      18266.0                  2540.0
# United States                28920.0                 15184.0
#
#                 Total.Minor.Injuries  Total.Uninjured
# Country_derive
# Foreign                       3740.0          84635.0
# United States                24715.0         319279.0

# %% [markdown]
# [uncomment the resetindex above]( https://stackoverflow.com/questions/39922986/pandas-group-by-and-sum)

# %%
df.groupby(['Country_derive']).sum().reset_index()
# Out:
#   Country_derive      Latitude     Longitude  Number.of.Engines  \
# 0        Foreign  2.354950e+04 -1.989426e+04             3180.0
# 1  United States  1.056490e+06 -2.665920e+06            86320.0
#
#    Total.Fatal.Injuries  Total.Serious.Injuries  Total.Minor.Injuries  \
# 0               18266.0                  2540.0                3740.0
# 1               28920.0                 15184.0               24715.0
#
#    Total.Uninjured
# 0          84635.0
# 1         319279.0

# %%
df.groupby(['Country_derive'])['Total.Uninjured'].agg('sum')
# Out:
# Country_derive
# Foreign           84635.0
# United States    319279.0
# Name: Total.Uninjured, dtype: float64

# %%
plot_categories(df,target='Total.Uninjured',cat='Country_derive')
# Out:
# /usr/local/lib/python3.6/dist-packages/seaborn/axisgrid.py:715: UserWarning: Using the barplot function without specifying `order` is likely to produce an incorrect plot.
#   warnings.warn(warning)

# %% [markdown]
# ### Check what kind of numeric data is there:
# Big value - 销量大不一定反映真正的市场需求，也可能是各店面中介先优惠价屯行程
#
# ### Number of distinct values per fields

# %%
df.describe()
# Out:
#            Latitude     Longitude  Number.of.Engines  Total.Fatal.Injuries  \
# count  28732.000000  28723.000000       78026.000000          56668.000000
# mean      37.590133    -93.507433           1.147054              0.832675
# std       12.316493     39.595652           0.447324              6.225796
# min      -78.016945   -178.676111           0.000000              0.000000
# 25%       33.346597   -114.927223           1.000000              0.000000
# 50%       38.147778    -94.371667           1.000000              0.000000
# 75%       42.533889    -81.644722           1.000000              1.000000
# max       89.218056    177.557778           4.000000            349.000000
#
#        Total.Serious.Injuries  Total.Minor.Injuries  Total.Uninjured
# count            54169.000000          55347.000000     68840.000000
# mean                 0.327198              0.514120         5.867432
# std                  1.375063              2.776149        29.444289
# min                  0.000000              0.000000         0.000000
# 25%                  0.000000              0.000000         0.000000
# 50%                  0.000000              0.000000         1.000000
# 75%                  0.000000              1.000000         2.000000
# max                111.000000            380.000000       699.000000

# %%
df_metadata=describe_more(df)
print(df_metadata)
# Out:
#                   Variable  Levels Datatype
# 1       Investigation.Type       2   object
# 16           Amateur.Built       2   object
# 27       Weather.Condition       3   object
# 20                Schedule       3   object
# 11         Aircraft.Damage       3   object
# 29           Report.Status       4   object
# 17       Number.of.Engines       5  float64
# 28   Broad.Phase.of.Flight      12   object
# 18             Engine.Type      13   object
# 12       Aircraft.Category      13   object
# 19         FAR.Description      18   object
# 21       Purpose.of.Flight      22   object
# 24  Total.Serious.Injuries      40  float64
# 25    Total.Minor.Injuries      63  float64
# 23    Total.Fatal.Injuries     124  float64
# 10         Injury.Severity     126   object
# 5                  Country     178   object
# 26         Total.Uninjured     371  float64
# 22             Air.Carrier    2976   object
# 30        Publication.Date    3813   object
# 14                    Make    7894   object
# 8             Airport.Code    9891   object
# 15                   Model   11771   object
# 3               Event.Date   13350   object
# 6                 Latitude   19515  float64
# 7                Longitude   21017  float64
# 9             Airport.Name   23453   object
# 4                 Location   26120   object
# 13     Registration.Number   71407   object
# 0                 Event.Id   81429   object
# 2          Accident.Number   82635   object

# %% [markdown]
# ### Review the same output, but by type of data

# %%
df_metadata.sort_values(by=['Datatype','Levels'])
# Out:
#                   Variable  Levels Datatype
# 17       Number.of.Engines       5  float64
# 24  Total.Serious.Injuries      40  float64
# 25    Total.Minor.Injuries      63  float64
# 23    Total.Fatal.Injuries     124  float64
# 26         Total.Uninjured     371  float64
# 6                 Latitude   19515  float64
# 7                Longitude   21017  float64
# 1       Investigation.Type       2   object
# 16           Amateur.Built       2   object
# 27       Weather.Condition       3   object
# 20                Schedule       3   object
# 11         Aircraft.Damage       3   object
# 29           Report.Status       4   object
# 28   Broad.Phase.of.Flight      12   object
# 18             Engine.Type      13   object
# 12       Aircraft.Category      13   object
# 19         FAR.Description      18   object
# 21       Purpose.of.Flight      22   object
# 10         Injury.Severity     126   object
# 5                  Country     178   object
# 22             Air.Carrier    2976   object
# 30        Publication.Date    3813   object
# 14                    Make    7894   object
# 8             Airport.Code    9891   object
# 15                   Model   11771   object
# 3               Event.Date   13350   object
# 9             Airport.Name   23453   object
# 4                 Location   26120   object
# 13     Registration.Number   71407   object
# 0                 Event.Id   81429   object
# 2          Accident.Number   82635   object

# %%
type(df_metadata.index)
df_metadata.set_index("Variable", drop = False)

df_metadata
# Out:
#                   Variable  Levels Datatype
# 1       Investigation.Type       2   object
# 16           Amateur.Built       2   object
# 27       Weather.Condition       3   object
# 20                Schedule       3   object
# 11         Aircraft.Damage       3   object
# 29           Report.Status       4   object
# 17       Number.of.Engines       5  float64
# 28   Broad.Phase.of.Flight      12   object
# 18             Engine.Type      13   object
# 12       Aircraft.Category      13   object
# 19         FAR.Description      18   object
# 21       Purpose.of.Flight      22   object
# 24  Total.Serious.Injuries      40  float64
# 25    Total.Minor.Injuries      63  float64
# 23    Total.Fatal.Injuries     124  float64
# 10         Injury.Severity     126   object
# 5                  Country     178   object
# 26         Total.Uninjured     371  float64
# 22             Air.Carrier    2976   object
# 30        Publication.Date    3813   object
# 14                    Make    7894   object
# 8             Airport.Code    9891   object
# 15                   Model   11771   object
# 3               Event.Date   13350   object
# 6                 Latitude   19515  float64
# 7                Longitude   21017  float64
# 9             Airport.Name   23453   object
# 4                 Location   26120   object
# 13     Registration.Number   71407   object
# 0                 Event.Id   81429   object
# 2          Accident.Number   82635   object

# %%
describe_more(df).sort_values(by=['Datatype','Levels'],ascending=[True,False])
# Out:
#                   Variable  Levels Datatype
# 7                Longitude   21017  float64
# 6                 Latitude   19515  float64
# 26         Total.Uninjured     371  float64
# 23    Total.Fatal.Injuries     124  float64
# 25    Total.Minor.Injuries      63  float64
# 24  Total.Serious.Injuries      40  float64
# 17       Number.of.Engines       5  float64
# 2          Accident.Number   82635   object
# 0                 Event.Id   81429   object
# 13     Registration.Number   71407   object
# 4                 Location   26120   object
# 9             Airport.Name   23453   object
# 3               Event.Date   13350   object
# 15                   Model   11771   object
# 8             Airport.Code    9891   object
# 14                    Make    7894   object
# 30        Publication.Date    3813   object
# 22             Air.Carrier    2976   object
# 5                  Country     178   object
# 10         Injury.Severity     126   object
# 21       Purpose.of.Flight      22   object
# 19         FAR.Description      18   object
# 18             Engine.Type      13   object
# 12       Aircraft.Category      13   object
# 28   Broad.Phase.of.Flight      12   object
# 29           Report.Status       4   object
# 27       Weather.Condition       3   object
# 20                Schedule       3   object
# 11         Aircraft.Damage       3   object
# 1       Investigation.Type       2   object
# 16           Amateur.Built       2   object

# %% [markdown]
# ## <font color='red'>以上写法有什么潜在问题？</font>

# %%
# a scatter plot comparing num_children and num_pets
df_metadata.plot(kind='scatter',x='Levels',y='Levels',color='red')
plt.show()

# %% [markdown]
# 能否看着这句代码：
# ### df_metadata.plot(kind='scatter',x='Levels',y='Levels',color='red')
#
# <font color='blue'>自己写下句画Bar chart?</font>

# %%
# Try to write your code below to draw Bar Chart:
#

# %% [markdown]
# # Reference answer below

# %%
df_metadata.plot(kind='bar',x='Variable',y='Levels',color='red')
plt.show()

# %%
# Data Transformation

df['Year'] = df['Event.Date'].apply(lambda d: datetime.datetime.strptime(d, "%Y-%m-%d").year)
df['Month'] = df['Event.Date'].apply(lambda d: datetime.datetime.strptime(d, "%Y-%m-%d").month)
df['Day'] = df['Event.Date'].apply(lambda d: datetime.datetime.strptime(d, "%Y-%m-%d").day)

df = df[df['Year'] >= 1982]

# %%
df
# Out:
#              Event.Id Investigation.Type Accident.Number  Event.Date  \
# 0      20181217X10943           Accident      GAA19CA098  2018-12-16
# 1      20181217X25746           Accident      GAA19CA097  2018-12-15
# 2      20181213X41114           Accident      ERA19LA065  2018-12-13
# 3      20181213X45528           Accident      CEN19FA044  2018-12-13
# 4      20181214X90303           Accident      GAA19CA096  2018-12-11
# 5      20181210X21905           Accident      GAA19CA091  2018-12-10
# 6      20181208X53536           Accident      GAA19CA090  2018-12-08
# 7      20181206X45049           Accident      GAA19CA088  2018-12-05
# 8      20181204X03049           Accident      GAA19CA086  2018-12-04
# 9      20181212X01623           Accident      ERA19LA063  2018-12-04
# 10     20181204X93009           Accident      GAA19CA087  2018-12-03
# 11     20181204X05247           Accident      WPR19LA035  2018-12-02
# 12     20181201X45922           Accident      ERA19FA060  2018-12-01
# 13     20181130X14057           Accident      ERA19FA059  2018-11-30
# 14     20181130X80724           Accident      CEN19LA039  2018-11-30
# 15     20181130X31617           Accident      CEN19FA036  2018-11-30
# 16     20181130X14309           Accident      WPR19WA033  2018-11-29
# 17     20181129X63138           Accident      GAA19CA080  2018-11-29
# 18     20181129X30228           Accident      ERA19LA057  2018-11-29
# 19     20181129X70430           Accident      CEN19FA035  2018-11-29
# 20     20181206X23959           Accident      WPR19WA038  2018-11-28
# 21     20181128X44044           Accident      GAA19CA085  2018-11-28
# 22     20181129X43605           Accident      GAA19CA083  2018-11-28
# 23     20181128X85901           Accident     GAA19CA079B  2018-11-28
# 24     20181128X85901           Accident     GAA19CA079A  2018-11-28
# 25     20181128X42306           Accident      GAA19CA078  2018-11-28
# 26     20181128X93322           Accident      GAA19CA084  2018-11-27
# 27     20181126X63346           Accident      GAA19CA075  2018-11-26
# 28     20181130X81333           Accident      ERA19WA058  2018-11-26
# 29     20181203X05042           Incident      ENG19WA005  2018-11-26
# ...               ...                ...             ...         ...
# 82598  20020917X02618           Accident      SEA82FA015  1982-01-04
# 82599  20020917X02410           Accident      MIA82FKA05  1982-01-04
# 82600  20020917X02254           Accident      LAX82FA038  1982-01-04
# 82601  20020917X01991           Accident      FTW82DA035  1982-01-04
# 82602  20020917X01880           Accident      CHI82FA019  1982-01-04
# 82603  20020917X02483           Accident      NYC82DA018  1982-01-03
# 82604  20020917X02340           Accident      MIA82DA030  1982-01-03
# 82605  20020917X02333           Incident      LAX82IA034  1982-01-03
# 82606  20020917X02255           Accident      LAX82FA040  1982-01-03
# 82607  20020917X02155           Accident      LAX82DA035  1982-01-03
# 82608  20020917X01992           Accident      FTW82DA036  1982-01-03
# 82609  20020917X01960           Accident      DEN82DTI09  1982-01-03
# 82610  20020917X01905           Accident      DCA82AA008  1982-01-03
# 82611  20020917X01720           Accident      ATL82FA033  1982-01-03
# 82612  20020917X02481           Accident      NYC82DA016  1982-01-02
# 82613  20020917X02339           Accident      MIA82DA028  1982-01-02
# 82614  20020917X02148           Accident      FTW82FRJ07  1982-01-02
# 82615  20020917X02134           Accident      FTW82FRA14  1982-01-02
# 82616  20020917X02119           Accident      FTW82FPJ10  1982-01-02
# 82617  20020917X02117           Accident      FTW82FPG08  1982-01-02
# 82618  20020917X01962           Accident      DEN82DTM08  1982-01-02
# 82619  20020917X01894           Accident      CHI82FEC08  1982-01-02
# 82620  20020917X01776           Accident      CHI82DA020  1982-01-02
# 82621  20020917X01657           Accident      ATL82DA027  1982-01-02
# 82622  20020917X01656           Accident      ANC82FAG14  1982-01-02
# 82623  20020909X01562           Accident      SEA82DA022  1982-01-01
# 82624  20020909X01561           Accident      NYC82DA015  1982-01-01
# 82625  20020909X01560           Accident      MIA82DA029  1982-01-01
# 82626  20020909X01559           Accident      FTW82DA034  1982-01-01
# 82627  20020909X01558           Accident      ATL82DKJ10  1982-01-01
#
#                         Location        Country   Latitude   Longitude  \
# 0                 Grangville, ID  United States  45.583611 -115.681667
# 1                   MORIARTY, NM  United States  34.970000 -106.000000
# 2                Punta Gorda, FL  United States  26.925278  -82.001111
# 3                 Valparaiso, IN  United States  41.451667  -87.004444
# 4                   Hartford, WI  United States  43.330278  -88.326111
# 5                    Chester, CT  United States        NaN         NaN
# 6                   Hesperia, CA  United States  34.376945 -117.316111
# 7                   Cornelia, GA  United States        NaN         NaN
# 8                       Reno, NV  United States  39.658889 -119.865833
# 9                     Moscow, PA  United States  41.326945  -75.591111
# 10                    Monroe, NC  United States  35.017500  -80.621945
# 11                Santa Rita, GU  United States        NaN         NaN
# 12           Fort Lauderdale, FL  United States  26.205000  -80.157222
# 13              Apalachicola, FL  United States  29.763611  -85.022500
# 14                     Fargo, ND  United States  46.920556  -96.815833
# 15                   Memphis, IN  United States  38.475278  -85.811111
# 16     Machadodorp, South Africa   South Africa -25.607778   30.514444
# 17                Burlington, WA  United States        NaN         NaN
# 18                  Kennesaw, GA  United States  34.039444  -84.585833
# 19                    Marion, IN  United States  40.480556  -85.682500
# 20      West Bangkala, Indonesia      Indonesia  -5.476389  119.523611
# 21            St. Petersburg, FL  United States        NaN         NaN
# 22                 Rock Hill, SC  United States  34.984722  -81.058056
# 23                      Mesa, AZ  United States  33.307778 -111.655556
# 24                      Mesa, AZ  United States  33.307778 -111.655556
# 25                  Americus, GA  United States  32.039722  -84.294166
# 26               Casa Grande, AZ  United States  32.955000 -111.766945
# 27                 Rio Vista, CA  United States  38.193333 -121.703611
# 28      Jequita?? County, Brazil         Brazil -18.512222  -44.555000
# 29         Addis Ababa, Ethiopia       Ethiopia        NaN         NaN
# ...                          ...            ...        ...         ...
# 82598          PLEASANT HILL, OR  United States        NaN         NaN
# 82599                SAINT CROIX            NaN        NaN         NaN
# 82600         NEAR LAS VEGAS, NV  United States        NaN         NaN
# 82601               ESTANCIA, NM  United States        NaN         NaN
# 82602             FORT WAYNE, IN  United States        NaN         NaN
# 82603           WHITE PLAINS, NY  United States        NaN         NaN
# 82604                  COCOA, FL  United States        NaN         NaN
# 82605               VAN NUYS, CA  United States        NaN         NaN
# 82606        10 NM W LEE VIN, CA  United States        NaN         NaN
# 82607         SAN CLEMENTINE, CA  United States        NaN         NaN
# 82608             FORT WORTH, TX  United States        NaN         NaN
# 82609              GREENOUGH, MT  United States        NaN         NaN
# 82610                ASHLAND, VA  United States        NaN         NaN
# 82611              PINEHURST, NC  United States        NaN         NaN
# 82612                GALETON, PA  United States        NaN         NaN
# 82613                  MIAMI, FL  United States        NaN         NaN
# 82614                  HOMER, LA  United States        NaN         NaN
# 82615                 HEARNE, TX  United States        NaN         NaN
# 82616              CHICKASHA, OK  United States        NaN         NaN
# 82617            LITTLE ROCK, AR  United States        NaN         NaN
# 82618                 MIDWAY, UT  United States        NaN         NaN
# 82619              YPSILANTI, MI  United States        NaN         NaN
# 82620              CHARLOTTE, MI  United States        NaN         NaN
# 82621               CHAMBLEE, GA  United States        NaN         NaN
# 82622                SKWENTA, AK  United States        NaN         NaN
# 82623                PULLMAN, WA  United States        NaN         NaN
# 82624           EAST HANOVER, NJ  United States        NaN         NaN
# 82625           JACKSONVILLE, FL  United States        NaN         NaN
# 82626                  HOBBS, NM  United States        NaN         NaN
# 82627               TUSKEGEE, AL  United States        NaN         NaN
#
#       Airport.Code                    Airport.Name  ...  \
# 0              PVT                             NaN  ...
# 1              NaN                   MORIARTY MUNI  ...
# 2              PGD                     Punta Gorda  ...
# 3              VPZ              Porter County Rgnl  ...
# 4              HXF                   Hartford Muni  ...
# 5              SNC                             NaN  ...
# 6              L26                        HESPERIA  ...
# 7              AJR                             NaN  ...
# 8              RTS                      RENO/STEAD  ...
# 9              NaN                             NaN  ...
# 10             EQY      CHARLOTTE-MONROE EXECUTIVE  ...
# 11             NaN                             NaN  ...
# 12             FXE  Fort Lauderdale Executive Airp  ...
# 13             AAF           Apalachicola Regional  ...
# 14             FAR            Hector International  ...
# 15             NaN                             NaN  ...
# 16             NaN                             NaN  ...
# 17             BVS                             NaN  ...
# 18             RYY  Cobb County Intl-Mccollum Fiel  ...
# 19             MZZ        Marion Municipal Airport  ...
# 20             NaN                             NaN  ...
# 21             SPG                  Albert Whitted  ...
# 22             UZA  ROCK HILL/YORK CO/BRYANT FIELD  ...
# 23             IWA            PHOENIX-MESA GATEWAY  ...
# 24             IWA            PHOENIX-MESA GATEWAY  ...
# 25             NaN                             NaN  ...
# 26             CGZ                CASA GRANDE MUNI  ...
# 27             O88                  Rio Vista Muni  ...
# 28            SNJI  Fazenda Fortaleza De Santa Air  ...
# 29             AAD  Addis Ababa Bole intl. Airport  ...
# ...            ...                             ...  ...
# 82598          NaN                             NaN  ...
# 82599          STX              ALEXANDER HAMILTON  ...
# 82600          NaN                             NaN  ...
# 82601          E92              ESTANCIA MUNICIPAL  ...
# 82602          NaN                             NaN  ...
# 82603          HPN              WESTCHESTER COUNTY  ...
# 82604          NaN                             NaN  ...
# 82605          VNY                        VAN NUYS  ...
# 82606          NaN                             NaN  ...
# 82607          NaN                             NaN  ...
# 82608          NaN                       OAK GROVE  ...
# 82609          NaN                             NaN  ...
# 82610          NaN                  HANOVER COUNTY  ...
# 82611          SOP                    MOORE COUNTY  ...
# 82612          5G6                  CHERRY SPRINGS  ...
# 82613          NaN                             NaN  ...
# 82614          NaN                             NaN  ...
# 82615          T72                HEARNE MUNICIPAL  ...
# 82616          NaN                             NaN  ...
# 82617          NaN                             NaN  ...
# 82618          NaN                     FIELD RANCH  ...
# 82619          YIP                      WILLOW RUN  ...
# 82620          49G                      TINKERBELL  ...
# 82621          PDK                             NaN  ...
# 82622          NaN                             NaN  ...
# 82623          NaN              BLACKBURN AG STRIP  ...
# 82624          N58                         HANOVER  ...
# 82625          JAX               JACKSONVILLE INTL  ...
# 82626          NaN                             NaN  ...
# 82627          NaN                        TUSKEGEE  ...
#
#       Total.Serious.Injuries Total.Minor.Injuries Total.Uninjured  \
# 0                        NaN                  NaN             1.0
# 1                        NaN                  NaN             1.0
# 2                        NaN                  1.0             NaN
# 3                        NaN                  NaN             NaN
# 4                        NaN                  NaN             1.0
# 5                        NaN                  NaN             NaN
# 6                        NaN                  NaN             1.0
# 7                        NaN                  NaN             2.0
# 8                        NaN                  NaN             2.0
# 9                        NaN                  NaN             1.0
# 10                       NaN                  NaN             1.0
# 11                       NaN                  2.0             NaN
# 12                       NaN                  1.0             NaN
# 13                       NaN                  NaN             NaN
# 14                       NaN                  9.0             2.0
# 15                       NaN                  NaN             NaN
# 16                       5.0                  NaN             NaN
# 17                       NaN                  NaN             1.0
# 18                       NaN                  2.0             NaN
# 19                       NaN                  NaN             NaN
# 20                       NaN                  NaN             2.0
# 21                       NaN                  NaN             1.0
# 22                       NaN                  NaN             2.0
# 23                       NaN                  NaN             7.0
# 24                       NaN                  NaN             7.0
# 25                       NaN                  NaN             1.0
# 26                       1.0                  NaN             NaN
# 27                       NaN                  NaN             1.0
# 28                       NaN                  NaN             NaN
# 29                       NaN                  NaN             NaN
# ...                      ...                  ...             ...
# 82598                    0.0                  0.0             0.0
# 82599                    0.0                  1.0             0.0
# 82600                    0.0                  0.0             0.0
# 82601                    0.0                  2.0             0.0
# 82602                    2.0                  0.0             0.0
# 82603                    0.0                  0.0             2.0
# 82604                    0.0                  1.0             1.0
# 82605                    0.0                  0.0             1.0
# 82606                    1.0                  0.0             0.0
# 82607                    0.0                  2.0             0.0
# 82608                    0.0                  2.0             0.0
# 82609                    0.0                  0.0             1.0
# 82610                    0.0                  0.0             0.0
# 82611                    0.0                  0.0             0.0
# 82612                    0.0                  0.0             1.0
# 82613                    0.0                  0.0             2.0
# 82614                    0.0                  1.0             0.0
# 82615                    0.0                  0.0             0.0
# 82616                    0.0                  0.0             0.0
# 82617                    0.0                  0.0             0.0
# 82618                    0.0                  0.0             1.0
# 82619                    0.0                  0.0             1.0
# 82620                    0.0                  0.0             2.0
# 82621                    0.0                  0.0             1.0
# 82622                    0.0                  0.0             0.0
# 82623                    0.0                  0.0             2.0
# 82624                    0.0                  0.0             2.0
# 82625                    0.0                  3.0             0.0
# 82626                    0.0                  0.0             1.0
# 82627                    0.0                  0.0             1.0
#
#       Weather.Condition Broad.Phase.of.Flight   Report.Status  \
# 0                   NaN                   NaN     Preliminary
# 1                   VMC                   NaN     Preliminary
# 2                   VMC              APPROACH     Preliminary
# 3                   VMC               TAKEOFF     Preliminary
# 4                   VMC                   NaN     Preliminary
# 5                   NaN                   NaN     Preliminary
# 6                   VMC                   NaN     Preliminary
# 7                   NaN                   NaN     Preliminary
# 8                   IMC                   NaN     Preliminary
# 9                   VMC                CRUISE     Preliminary
# 10                  VMC                   NaN     Preliminary
# 11                  VMC                   NaN     Preliminary
# 12                  VMC               TAKEOFF     Preliminary
# 13                  VMC               TAKEOFF     Preliminary
# 14                  IMC               LANDING     Preliminary
# 15                  VMC               TAKEOFF     Preliminary
# 16                  NaN                CRUISE         Foreign
# 17                  NaN                   NaN     Preliminary
# 18                  VMC                CRUISE     Preliminary
# 19                  VMC               TAKEOFF     Preliminary
# 20                  NaN                   NaN         Foreign
# 21                  NaN                   NaN     Preliminary
# 22                  VMC                   NaN     Preliminary
# 23                  VMC                   NaN     Preliminary
# 24                  VMC                   NaN     Preliminary
# 25                  VMC                   NaN     Preliminary
# 26                  VMC                   NaN     Preliminary
# 27                  VMC                   NaN     Preliminary
# 28                  NaN             GO-AROUND         Foreign
# 29                  NaN               TAKEOFF         Foreign
# ...                 ...                   ...             ...
# 82598               VMC                CRUISE  Probable Cause
# 82599               VMC                  TAXI  Probable Cause
# 82600               VMC                CRUISE  Probable Cause
# 82601               VMC                CRUISE  Probable Cause
# 82602               IMC                CRUISE  Probable Cause
# 82603               VMC               LANDING  Probable Cause
# 82604               VMC               DESCENT  Probable Cause
# 82605               VMC              APPROACH  Probable Cause
# 82606               IMC               DESCENT  Probable Cause
# 82607               VMC           MANEUVERING  Probable Cause
# 82608               VMC              APPROACH  Probable Cause
# 82609               VMC               TAKEOFF  Probable Cause
# 82610               IMC              APPROACH  Probable Cause
# 82611               IMC              APPROACH  Probable Cause
# 82612               VMC                  TAXI  Probable Cause
# 82613               VMC                CRUISE  Probable Cause
# 82614               IMC                CRUISE  Probable Cause
# 82615               IMC               TAKEOFF  Probable Cause
# 82616               IMC                CRUISE  Probable Cause
# 82617               IMC                CRUISE  Probable Cause
# 82618               IMC                  TAXI  Probable Cause
# 82619               VMC               TAKEOFF  Probable Cause
# 82620               VMC              APPROACH  Probable Cause
# 82621               VMC              APPROACH  Probable Cause
# 82622               VMC               UNKNOWN  Probable Cause
# 82623               VMC               TAKEOFF  Probable Cause
# 82624               IMC               LANDING  Probable Cause
# 82625               IMC                CRUISE  Probable Cause
# 82626               VMC              APPROACH  Probable Cause
# 82627               VMC               LANDING  Probable Cause
#
#       Publication.Date  Year Month Day
# 0           2018-12-18  2018    12  16
# 1           2018-12-20  2018    12  15
# 2           2018-12-21  2018    12  13
# 3           2018-12-19  2018    12  13
# 4           2018-12-18  2018    12  11
# 5           2018-12-13  2018    12  10
# 6           2018-12-13  2018    12   8
# 7           2018-12-13  2018    12   5
# 8           2018-12-20  2018    12   4
# 9           2018-12-19  2018    12   4
# 10          2018-12-07  2018    12   3
# 11          2018-12-11  2018    12   2
# 12          2018-12-17  2018    12   1
# 13          2018-12-11  2018    11  30
# 14          2018-12-17  2018    11  30
# 15          2018-12-13  2018    11  30
# 16                 NaN  2018    11  29
# 17          2018-12-13  2018    11  29
# 18          2018-12-11  2018    11  29
# 19          2018-12-10  2018    11  29
# 20                 NaN  2018    11  28
# 21          2018-12-04  2018    11  28
# 22          2018-12-20  2018    11  28
# 23          2018-11-29  2018    11  28
# 24          2018-11-29  2018    11  28
# 25          2018-12-10  2018    11  28
# 26          2018-12-10  2018    11  27
# 27          2018-12-11  2018    11  26
# 28                 NaN  2018    11  26
# 29                 NaN  2018    11  26
# ...                ...   ...   ...  ..
# 82598       1983-01-04  1982     1   4
# 82599       1983-01-04  1982     1   4
# 82600       1983-01-04  1982     1   4
# 82601       1983-01-04  1982     1   4
# 82602       1983-01-04  1982     1   4
# 82603       1983-01-03  1982     1   3
# 82604       1983-01-03  1982     1   3
# 82605       1983-01-03  1982     1   3
# 82606       1983-01-03  1982     1   3
# 82607       1983-01-03  1982     1   3
# 82608       1983-01-03  1982     1   3
# 82609       1983-01-03  1982     1   3
# 82610       1983-01-03  1982     1   3
# 82611       1983-01-03  1982     1   3
# 82612       1983-01-02  1982     1   2
# 82613       1983-01-02  1982     1   2
# 82614       1983-01-02  1982     1   2
# 82615       1983-01-02  1982     1   2
# 82616       1983-01-02  1982     1   2
# 82617       1983-01-02  1982     1   2
# 82618       1983-01-02  1982     1   2
# 82619       1983-01-02  1982     1   2
# 82620       1983-01-02  1982     1   2
# 82621       1983-01-02  1982     1   2
# 82622       1983-01-02  1982     1   2
# 82623       1982-01-01  1982     1   1
# 82624       1982-01-01  1982     1   1
# 82625       1982-01-01  1982     1   1
# 82626       1982-01-01  1982     1   1
# 82627       1982-01-01  1982     1   1
#
# [82628 rows x 34 columns]

# %%
objects = ('Boeing','Airbus','Piper','Yun10','运','Gulfstream')
    #'SQL', 'Java', 'Python', 'Alteryx', 'Power BI', 'R')
y_pos = np.arange(len(objects))
#print(y_pos)
performance = [10,8,6,4,2,1]

plt.bar(y_pos, performance, align='center', alpha=0.5)
plt.xticks(y_pos, objects)
plt.ylabel('Usage')
plt.title('Data Analysis job market tools survey')

plt.show()

# %%
print("\\")
# Out:
# \

# %% [markdown]
# 两种过滤Data Frame办法

# %%
categories=df_metadata[df_metadata['Datatype']=="object"]['Variable']

Flag_category=df_metadata['Datatype']=="object"

print (categories)

countries=df['Country']

#countries=countries[~np.isnan(countries)]
countries.drop_duplicates( keep='first', inplace=True)
print("There are %s countries:"%countries.count())
print (countries)
# Out:
# 1        Investigation.Type
# 16            Amateur.Built
# 27        Weather.Condition
# 20                 Schedule
# 11          Aircraft.Damage
# 29            Report.Status
# 28    Broad.Phase.of.Flight
# 18              Engine.Type
# 12        Aircraft.Category
# 19          FAR.Description
# 21        Purpose.of.Flight
# 10          Injury.Severity
# 5                   Country
# 22              Air.Carrier
# 30         Publication.Date
# 14                     Make
# 8              Airport.Code
# 15                    Model
# 3                Event.Date
# 9              Airport.Name
# 4                  Location
# 13      Registration.Number
# 0                  Event.Id
# 2           Accident.Number
# Name: Variable, dtype: object
# There are 178 countries:
# 0                         United States
# 16                         South Africa
# 20                            Indonesia
# 28                               Brazil
# 29                             Ethiopia
# 32                            Australia
# 37                   Dominican Republic
# 41                                Chile
# 69                               Mexico
# 80                              Bahamas
# 81                               Norway
# 119                      United Kingdom
# 145                         New Zealand
# 160                              Sweden
# 197                         Switzerland
# 203                             Nigeria
# 210                               Italy
# 219                              Russia
# 236      Federated States Of Micronesia
# 239                               Japan
# 245                              Canada
# 304                              Guyana
# 322                              Turkey
# 323                             Ukraine
# 330                      Czech Republic
# 380                              Belize
# 410                            Bulgaria
# 419                          Costa Rica
# 499                             Germany
# 500                          Mauritania
#                       ...
# 19177                            Uganda
# 19508                  French Polynesia
# 19879                               NaN
# 19915                            Malawi
# 21404          Northern Mariana Islands
# 22357                            Gambia
# 25174                            Zambia
# 25371                      Sierra Leone
# 26573                        Martinique
# 26597                             Benin
# 26627                             Gabon
# 29667          Central African Republic
# 30019                         Gibraltar
# 30103                           Tunisia
# 31446                           Eritrea
# 32573                       Ivory Coast
# 33235                             Niger
# 34236                       West Indies
# 34675                       Isle of Man
# 34858                     Cote D'ivoire
# 35820                           Liberia
# 40480                         Mauritius
# 40957                          Cambodia
# 41357               Antigua And Barbuda
# 41476                             Aruba
# 43868                             Malta
# 46723                          St Lucia
# 52825                           Senegal
# 55371                        Montserrat
# 56339                          Anguilla
# Name: Country, Length: 179, dtype: object
# /usr/local/lib/python3.6/dist-packages/pandas/core/base.py:1512: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   return self._update_inplace(result)

# %% [markdown]
# def category_values(dataframe, categories):
#     for c in categories:
#         print('\n', dataframe.groupby(by=c)[c].count().sort_values(ascending=False))
#         print('Nulls: ', dataframe[c].isnull().sum())

# %% [markdown]
# ## TOO LONG DNR

# %%
for c in categories:
    print(c , df[c].unique())

#df[df['first_name'].notnull() & (df['nationality'] == "USA")]
# Out:
# Investigation.Type ['Accident' 'Incident' nan]
# Amateur.Built ['No' 'Yes' nan]
# Weather.Condition [nan 'VMC' 'IMC' 'UNK']
# Schedule [nan 'SCHD' 'NSCH' 'UNK']
# Aircraft.Damage ['Substantial' 'Destroyed' 'Minor' nan]
# Report.Status ['Preliminary' 'Foreign' 'Factual' 'Probable Cause']
# Broad.Phase.of.Flight [nan 'APPROACH' 'TAKEOFF' 'CRUISE' 'LANDING' 'GO-AROUND' 'UNKNOWN' 'TAXI'
#  'OTHER' 'DESCENT' 'MANEUVERING' 'STANDING' 'CLIMB']
# Engine.Type [nan 'Reciprocating' 'Turbo Jet' 'Turbo Fan' 'Turbo Prop' 'Turbo Shaft'
#  'Unknown' 'None' 'Electric' 'REC, ELEC' 'Hybrid Rocket' 'REC, TJ, TJ'
#  'REC, TJ, REC, TJ' 'TJ, REC, REC, TJ']
# Aircraft.Category ['Airplane' 'Helicopter' 'Gyroplane' nan 'Balloon' 'Unknown'
#  'Weight-Shift' 'Glider' 'Ultralight' 'Powered Parachute' 'Blimp'
#  'Powered-Lift' 'Gyrocraft' 'Rocket']
# FAR.Description ['Part 91: General Aviation' 'Non-U.S., Non-Commercial'
#  'Part 135: Air Taxi & Commuter' 'Part 137: Agricultural'
#  'Non-U.S., Commercial' 'Part 133: Rotorcraft Ext. Load' 'Unknown'
#  'Part 129: Foreign' 'Public Aircraft' 'Part 121: Air Carrier' nan
#  'Part 103: Ultralight' 'Part 91 Subpart K: Fractional' 'Armed Forces'
#  'Part 107: Small UAS' 'Public Use' 'Part 437: Commercial Space Flight'
#  'Part 125: 20+ Pax,6000+ lbs' 'Part 91F: Special Flt Ops.']
# Purpose.of.Flight ['Positioning' 'Personal' nan 'Instructional' 'Business'
#  'Aerial Application' 'Unknown' 'Flight Test' 'External Load'
#  'Aerial Observation' 'Firefighting' 'Air Race/Show' 'Other Work Use'
#  'Ferry' 'Public Aircraft - Federal' 'Skydiving' 'Public Aircraft - Local'
#  'Banner Tow' 'Public Aircraft' 'Public Aircraft - State' 'Glider Tow'
#  'Executive/Corporate' 'Air Drop']
# Injury.Severity ['Non-Fatal' 'Fatal(1)' 'Unavailable' 'Fatal(2)' 'Fatal(3)' 'Fatal(4)'
#  'Incident' 'Fatal(5)' 'Fatal(9)' 'Fatal(10)' 'Fatal(112)' 'Fatal(6)'
#  'Fatal(71)' 'Fatal(12)' 'Fatal(11)' 'Fatal(7)' 'Fatal(39)' 'Fatal(8)'
#  'Fatal(16)' 'Fatal(66)' 'Fatal(62)' 'Fatal(23)' 'Fatal(224)' 'Fatal(150)'
#  'Fatal(43)' 'Fatal(162)' 'Fatal(58)' 'Fatal(295)' 'Fatal(239)'
#  'Fatal(33)' 'Fatal(50)' 'Fatal(14)' 'Fatal(21)' 'Fatal(19)' 'Fatal(153)'
#  'Fatal(127)' 'Fatal(28)' 'Fatal(77)' 'Fatal(42)' 'Fatal(157)'
#  'Fatal(158)' 'Fatal(103)' 'Fatal(89)' 'Fatal(90)' 'Fatal(152)'
#  'Fatal(228)' 'Fatal(17)' 'Fatal(13)' 'Fatal(24)' 'Fatal(88)' 'Fatal(65)'
#  'Fatal(154)' 'Fatal(30)' 'Fatal(20)' 'Fatal(40)' 'Fatal(57)' 'Fatal(199)'
#  'Fatal(114)' 'Fatal(102)' 'Fatal(96)' 'Fatal(49)' 'Fatal(124)'
#  'Fatal(113)' 'Fatal(107)' 'Fatal(117)' 'Fatal(145)' 'Fatal(45)'
#  'Fatal(160)' 'Fatal(121)' 'Fatal(15)' 'Fatal(104)' 'Fatal(25)'
#  'Fatal(55)' 'Fatal(46)' 'Fatal(141)' 'Fatal(115)' 'Fatal(75)'
#  'Fatal(206)' 'Fatal(138)' 'Fatal(92)' 'Fatal(26)' 'Fatal(265)'
#  'Fatal(118)' 'Fatal(44)' 'Fatal(64)' 'Fatal(18)' 'Fatal(83)' 'Fatal(143)'
#  'Fatal(60)' 'Fatal(131)' 'Fatal(169)' 'Fatal(217)' 'Fatal(80)'
#  'Fatal(229)' 'Fatal(87)' 'Fatal(52)' 'Fatal(97)' 'Fatal(35)' 'Fatal(29)'
#  'Fatal(125)' 'Fatal(349)' 'Fatal(34)' 'Fatal(70)' 'Fatal(230)'
#  'Fatal(110)' 'Fatal(123)' 'Fatal(189)' 'Fatal(72)' 'Fatal(54)'
#  'Fatal(68)' 'Fatal(132)' 'Fatal(37)' 'Fatal(56)' 'Fatal(47)' 'Fatal(27)'
#  'Fatal(73)' 'Fatal(111)' 'Fatal(174)' 'Fatal(144)' 'Fatal(270)'
#  'Fatal(156)' 'Fatal(82)' 'Fatal(256)' 'Fatal(31)' 'Fatal(135)'
#  'Fatal(78)']
# Country ['United States' 'South Africa' 'Indonesia' 'Brazil' 'Ethiopia'
#  'Australia' 'Dominican Republic' 'Chile' 'Mexico' 'Bahamas' 'Norway'
#  'United Kingdom' 'New Zealand' 'Sweden' 'Switzerland' 'Nigeria' 'Italy'
#  'Russia' 'Federated States Of Micronesia' 'Japan' 'Canada' 'Guyana'
#  'Turkey' 'Ukraine' 'Czech Republic' 'Belize' 'Bulgaria' 'Costa Rica'
#  'Germany' 'Mauritania' 'France' 'Romania' 'Paraguay' 'Ireland' 'Austria'
#  'British Virgin Islands' 'Argentina' 'Poland' 'Portugal' 'Slovakia'
#  'Taiwan' 'India' 'Singapore' 'China' 'Madagascar' 'Spain' 'Kenya'
#  'Netherlands' 'Ecuador' 'Colombia' 'Honduras' 'Cuba' 'Saudi Arabia'
#  'Guatemala' 'Jamaica' 'French Guiana' 'Bermuda' 'Hong Kong' 'Kyrgyzstan'
#  'Greenland' 'Marshall Islands' 'United Arab Emirates' 'Israel' 'Peru'
#  'Philippines' 'Finland' 'Turks And Caicos Islands' 'Egypt' 'Kazakhstan'
#  'Latvia' 'Tanzania' 'Pakistan' 'Belgium' 'Thailand' 'Venezuela' 'Algeria'
#  'Hungary' 'Greece' 'Korea, Republic Of' 'Suriname' 'Denmark' 'Iceland'
#  'Malaysia' 'Iran' 'Netherlands Antilles' 'Jordan' 'Guadeloupe' 'Unknown'
#  'El Salvador' 'Panama' 'Nepal' 'Macedonia' 'Slovenia' 'Cayman Islands'
#  'Lithuania' 'American Samoa' 'Qatar' 'Nicaragua' 'Cyprus' 'Kiribati'
#  'Papua New Guinea' 'Croatia' 'Belarus' 'Nauru' 'Cameroon' 'Reunion'
#  'Uruguay' 'Afghanistan' 'Yemen' 'New Caledonia' 'Mali' 'Bolivia'
#  'Solomon Islands' 'Namibia' 'Luxembourg' 'Trinidad And Tobago'
#  'Bangladesh' 'Oman' 'Burma' 'Morocco' 'Botswana' 'Ghana' 'Vietnam'
#  'Bosnia And Herzegovina' 'Estonia' 'Congo' 'Antarctica' 'Maldives'
#  'Angola' 'Haiti' 'Dominica' 'Vanuatu' 'Barbados' 'Iraq' 'Mozambique'
#  'St Vincent And The Grenadines' 'Guinea' 'Libya' 'Fiji' 'Bahrain'
#  'Lebanon' 'Palau' 'Rwanda' 'Zimbabwe' 'St Kitts And Nevis' 'Comoros'
#  'Sudan' 'Laos' 'Serbia' 'Uganda' 'French Polynesia' nan 'Malawi'
#  'Northern Mariana Islands' 'Gambia' 'Zambia' 'Sierra Leone' 'Martinique'
#  'Benin' 'Gabon' 'Central African Republic' 'Gibraltar' 'Tunisia'
#  'Eritrea' 'Ivory Coast' 'Niger' 'West Indies' 'Isle of Man'
#  "Cote D'ivoire" 'Liberia' 'Mauritius' 'Cambodia' 'Antigua And Barbuda'
#  'Aruba' 'Malta' 'St Lucia' 'Senegal' 'Montserrat' 'Anguilla']
# Air.Carrier [nan 'Daylight Nightlight Ez Flight Llc' 'Westair, Inc.' ...
#  'EXECUTIVE CHARTER SERVICE' 'LANG AIR SERVICE'
#  'ROCKY MOUNTAIN HELICOPTERS, IN']
# Publication.Date ['2018-12-18' '2018-12-20' '2018-12-21' ... '1983-01-03' '1983-01-02'
#  '1982-01-01']
# Make ['Cessna' 'CZECH SPORT AIRCRAFT AS' 'Piper' ... 'ROCKWELL COMDR'
#  'BELL/TEXTRON' 'SONS MUSTANG']
# Airport.Code ['PVT' nan 'PGD' ... 'SC42' '5G6' '49G']
# Model ['170' '180' 'Piper Sport' ... '23-250' '305 (L-19)' 'WCS-222 (BELL 47G)']
# Event.Date ['2018-12-16' '2018-12-15' '2018-12-13' ... '1982-01-03' '1982-01-02'
#  '1982-01-01']
# Airport.Name [nan 'MORIARTY MUNI' 'Punta Gorda' ... 'FIELD RANCH' 'TINKERBELL'
#  'BLACKBURN AG STRIP']
# Location ['Grangville, ID' 'MORIARTY, NM' 'Punta Gorda, FL' ... 'GREENOUGH, MT'
#  'GALETON, PA' 'MIDWAY, UT']
# Registration.Number ['N4385B' 'N188H' 'N145MM' ... 'N3906K' 'N44832' 'N4275S']
# Event.Id ['20181217X10943' '20181217X25746' '20181213X41114' ... '20020909X01560'
#  '20020909X01559' '20020909X01558']
# Accident.Number ['GAA19CA098' 'GAA19CA097' 'ERA19LA065' ... 'MIA82DA029' 'FTW82DA034'
#  'ATL82DKJ10']

# %% [markdown]
# ## <font color='red'>Will fail</font>

# %%
for c in categories:
    print(c , df[c].unique().sample(5))
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-22-20df47cdfb49> in <module>()
#       1 for c in categories:
# ----> 2     print(c , df[c].unique().sample(5))
#
# AttributeError: 'numpy.ndarray' object has no attribute 'sample'

# %%
df[countries]
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-28-6796d418590d> in <module>()
# ----> 1 df[countries]
#       2
#
# /usr/local/lib/python3.6/dist-packages/pandas/core/frame.py in __getitem__(self, key)
#    2915
#    2916         # Do we have a (boolean) 1d indexer?
# -> 2917         if com.is_bool_indexer(key):
#    2918             return self._getitem_bool_array(key)
#    2919
#
# /usr/local/lib/python3.6/dist-packages/pandas/core/common.py in is_bool_indexer(key)
#     122             if not lib.is_bool_array(key):
#     123                 if isna(key).any():
# --> 124                     raise ValueError(na_msg)
#     125                 return False
#     126             return True
#
# ValueError: cannot index with vector containing NA / NaN values

# %%
category_values(df, categories)
#print(countries)
#category_values(df, countries)
# Out:
#  Investigation.Type
# Accident    79282
# Incident     3345
# Name: Investigation.Type, dtype: int64
# Nulls:  1
#
#  Amateur.Built
# No     73946
# Yes     8055
# Name: Amateur.Built, dtype: int64
# Nulls:  627
#
#  Weather.Condition
# VMC    73108
# IMC     5781
# UNK     1031
# Name: Weather.Condition, dtype: int64
# Nulls:  2708
#
#  Schedule
# UNK     4099
# NSCH    3983
# SCHD    3647
# Name: Schedule, dtype: int64
# Nulls:  70899
#
#  Aircraft.Damage
# Substantial    59650
# Destroyed      17780
# Minor           2606
# Name: Aircraft.Damage, dtype: int64
# Nulls:  2592
#
#  Report.Status
# Probable Cause    76093
# Foreign            4503
# Preliminary        1458
# Factual             574
# Name: Report.Status, dtype: int64
# Nulls:  0
#
#  Broad.Phase.of.Flight
# LANDING        20115
# TAKEOFF        15935
# CRUISE         10966
# MANEUVERING    10189
# APPROACH        8010
# TAXI            2413
# CLIMB           2339
# DESCENT         2278
# GO-AROUND       1678
# STANDING        1276
# UNKNOWN          756
# OTHER            170
# Name: Broad.Phase.of.Flight, dtype: int64
# Nulls:  6503
#
#  Engine.Type
# Reciprocating       66874
# Turbo Shaft          3442
# Turbo Prop           3220
# Turbo Fan            2334
# Unknown              2056
# Turbo Jet             696
# None                   15
# Electric                4
# REC, TJ, TJ             2
# TJ, REC, REC, TJ        1
# REC, TJ, REC, TJ        1
# REC, ELEC               1
# Hybrid Rocket           1
# Name: Engine.Type, dtype: int64
# Nulls:  3981
#
#  Aircraft.Category
# Airplane             22192
# Helicopter            2742
# Glider                 431
# Balloon                192
# Weight-Shift            92
# Gyrocraft               89
# Powered Parachute       59
# Gyroplane               48
# Ultralight              30
# Unknown                 14
# Powered-Lift             5
# Blimp                    4
# Rocket                   1
# Name: Aircraft.Category, dtype: int64
# Nulls:  56729
#
#  FAR.Description
# Part 91: General Aviation            20425
# Part 137: Agricultural                1229
# Non-U.S., Non-Commercial               949
# Part 135: Air Taxi & Commuter          867
# Part 121: Air Carrier                  641
# Non-U.S., Commercial                   583
# Unknown                                272
# Part 129: Foreign                      226
# Public Use                             155
# Part 133: Rotorcraft Ext. Load         111
# Public Aircraft                         69
# Part 91 Subpart K: Fractional           15
# Armed Forces                            10
# Part 125: 20+ Pax,6000+ lbs              8
# Part 103: Ultralight                     3
# Part 437: Commercial Space Flight        1
# Part 107: Small UAS                      1
# Part 91F: Special Flt Ops.               1
# Name: FAR.Description, dtype: int64
# Nulls:  57062
#
#  Purpose.of.Flight
# Personal                     46333
# Instructional                 9894
# Unknown                       6790
# Aerial Application            4496
# Business                      3951
# Positioning                   1552
# Other Work Use                1153
# Ferry                          794
# Aerial Observation             715
# Public Aircraft                713
# Executive/Corporate            522
# Flight Test                    341
# Skydiving                      170
# Air Race/Show                  161
# Public Aircraft - Federal       97
# External Load                   94
# Banner Tow                      89
# Public Aircraft - State         64
# Public Aircraft - Local         63
# Glider Tow                      49
# Firefighting                    27
# Air Drop                        11
# Name: Purpose.of.Flight, dtype: int64
# Nulls:  4549
#
#  Injury.Severity
# Non-Fatal      62450
# Fatal(1)        8190
# Fatal(2)        4824
# Incident        3345
# Fatal(3)        1506
# Fatal(4)        1053
# Fatal(5)         330
# Unavailable      257
# Fatal(6)         204
# Fatal(7)          85
# Fatal(8)          66
# Fatal(10)         44
# Fatal(9)          39
# Fatal(14)         17
# Fatal(11)         17
# Fatal(12)         11
# Fatal(13)         11
# Fatal(20)          6
# Fatal(15)          5
# Fatal(23)          5
# Fatal(17)          5
# Fatal(19)          5
# Fatal(18)          5
# Fatal(21)          4
# Fatal(16)          4
# Fatal(25)          4
# Fatal(154)         3
# Fatal(34)          3
# Fatal(71)          3
# Fatal(65)          3
#                ...
# Fatal(66)          1
# Fatal(68)          1
# Fatal(72)          1
# Fatal(73)          1
# Fatal(77)          1
# Fatal(78)          1
# Fatal(80)          1
# Fatal(83)          1
# Fatal(45)          1
# Fatal(44)          1
# Fatal(42)          1
# Fatal(40)          1
# Fatal(189)         1
# Fatal(199)         1
# Fatal(206)         1
# Fatal(217)         1
# Fatal(224)         1
# Fatal(229)         1
# Fatal(239)         1
# Fatal(96)          1
# Fatal(26)          1
# Fatal(265)         1
# Fatal(270)         1
# Fatal(295)         1
# Fatal(31)          1
# Fatal(35)          1
# Fatal(37)          1
# Fatal(39)          1
# Fatal(90)          1
# Fatal(256)         1
# Name: Injury.Severity, Length: 126, dtype: int64
# Nulls:  0
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-42-b27f4e8c5277> in <module>()
# ----> 1 category_values(df, categories)
#       2 #print(countries)
#       3 #category_values(df, countries)
#
# <ipython-input-5-1031abcdd49f> in category_values(dataframe, categories)
#      66 def category_values(dataframe, categories):
#      67     for c in categories:
# ---> 68         print('\n', dataframe.groupby(by=c)[c].count().sort_values(ascending=False))
#      69         print('Nulls: ', dataframe[c].isnull().sum())
#
# /usr/local/lib/python3.6/dist-packages/pandas/core/groupby/generic.py in count(self)
#    1208         val = self.obj.get_values()
#    1209
# -> 1210         mask = (ids != -1) & ~isna(val)
#    1211         ids = ensure_platform_int(ids)
#    1212         minlength = ngroups or (None if _np_version_under1p13 else 0)
#
# ValueError: operands could not be broadcast together with shapes (82628,) (179,)

# %%
print(df.groupby(['Make','Amateur.Built']).count())
#print(df.groupby(['Weather.Condition','Aircraft.Damage']).count())
# Out:
#                                         Event.Id  Investigation.Type  \
# Make                     Amateur.Built
# 107.5 Flying Corporation Yes                   1                   1
# 1200                     No                    1                   1
# 177MF LLC                Yes                   1                   1
# 1977 COLFER-CHAN         Yes                   1                   1
# 1ST FTR GP               Yes                   1                   1
# 2001 MCGIRL              Yes                   1                   1
# 2003 Nash                Yes                   1                   1
# 2007 Savage Air LLC      Yes                   1                   1
# 3XTRIM                   No                    1                   1
# 67 FLYING DUTCHMAN       Yes                   1                   1
# 781569 INC               Yes                   1                   1
# 85 MANISTA               Yes                   1                   1
# A Pair of Jacks          Yes                   1                   1
# A. H. GETTINGS           Yes                   1                   1
# A. LE FRANCOIS           Yes                   1                   1
# A. Schleicher GMBH & Co. No                    1                   1
# AAA Aircraft Leasing     No                    1                   1
# AARDEMA ROBERT JOHN      Yes                   1                   1
# AB SPORTINE AVIACIJA     No                    4                   4
# AB Sportine Aviacija     No                    2                   2
#                          Yes                   1                   1
# ABBEY VICTOR             Yes                   1                   1
# ABBOTT                   Yes                   1                   1
# ABC                      No                    1                   1
# ABERNATHY                Yes                   1                   1
# ABRAMS/NUDING            Yes                   1                   1
# AC Mfg & Dev't Co        No                    1                   1
# ACKLAND JEFFREY DEAN     Yes                   1                   1
# ACRODUSTER               Yes                   1                   1
# ADAMS                    No                    6                   6
# ...                                          ...                 ...
# ZWICKER MURRAY R         Yes                   1                   1
# Zacharius                Yes                   1                   1
# Zaverton Elmer           Yes                   1                   1
# Zawada                   Yes                   1                   1
# Zdybel                   Yes                   1                   1
# Zeidler                  Yes                   1                   1
# Zeidman                  Yes                   1                   1
# Zenair                   No                    5                   5
#                          Yes                   7                   7
# Zenith                   Yes                   2                   2
# Zhuhai Helicopter Co.    Yes                   1                   1
# Zidek                    Yes                   1                   1
# Zielke                   Yes                   1                   1
# Ziermann                 Yes                   1                   1
# Zilz                     Yes                   1                   1
# Zimmerman                Yes                   2                   2
# Zito                     Yes                   1                   1
# Zivko                    Yes                   1                   1
# Zivko Aeronautics Inc.   Yes                   1                   1
# Zlin                     No                    2                   2
# Zlin Aviation s.r.o.     No                    1                   1
# Zorn                     Yes                   1                   1
# Zwart                    Yes                   1                   1
# bourque experimental     Yes                   1                   1
# de HAVILLAND             No                    1                   1
# de Havilland             No                  311                 311
#                          Yes                   1                   1
# deHAVILLAND              No                    2                   2
# deHavilland              No                    3                   3
# unknown                  Yes                   3                   3
#
#                                         Accident.Number  Event.Date  Location  \
# Make                     Amateur.Built
# 107.5 Flying Corporation Yes                          1           1         1
# 1200                     No                           1           1         1
# 177MF LLC                Yes                          1           1         1
# 1977 COLFER-CHAN         Yes                          1           1         1
# 1ST FTR GP               Yes                          1           1         1
# 2001 MCGIRL              Yes                          1           1         1
# 2003 Nash                Yes                          1           1         1
# 2007 Savage Air LLC      Yes                          1           1         1
# 3XTRIM                   No                           1           1         1
# 67 FLYING DUTCHMAN       Yes                          1           1         1
# 781569 INC               Yes                          1           1         1
# 85 MANISTA               Yes                          1           1         1
# A Pair of Jacks          Yes                          1           1         1
# A. H. GETTINGS           Yes                          1           1         1
# A. LE FRANCOIS           Yes                          1           1         1
# A. Schleicher GMBH & Co. No                           1           1         1
# AAA Aircraft Leasing     No                           1           1         1
# AARDEMA ROBERT JOHN      Yes                          1           1         1
# AB SPORTINE AVIACIJA     No                           4           4         4
# AB Sportine Aviacija     No                           2           2         2
#                          Yes                          1           1         1
# ABBEY VICTOR             Yes                          1           1         1
# ABBOTT                   Yes                          1           1         1
# ABC                      No                           1           1         1
# ABERNATHY                Yes                          1           1         1
# ABRAMS/NUDING            Yes                          1           1         1
# AC Mfg & Dev't Co        No                           1           1         1
# ACKLAND JEFFREY DEAN     Yes                          1           1         1
# ACRODUSTER               Yes                          1           1         1
# ADAMS                    No                           6           6         6
# ...                                                 ...         ...       ...
# ZWICKER MURRAY R         Yes                          1           1         1
# Zacharius                Yes                          1           1         1
# Zaverton Elmer           Yes                          1           1         1
# Zawada                   Yes                          1           1         1
# Zdybel                   Yes                          1           1         1
# Zeidler                  Yes                          1           1         1
# Zeidman                  Yes                          1           1         1
# Zenair                   No                           5           5         5
#                          Yes                          7           7         7
# Zenith                   Yes                          2           2         2
# Zhuhai Helicopter Co.    Yes                          1           1         1
# Zidek                    Yes                          1           1         1
# Zielke                   Yes                          1           1         1
# Ziermann                 Yes                          1           1         1
# Zilz                     Yes                          1           1         1
# Zimmerman                Yes                          2           2         2
# Zito                     Yes                          1           1         1
# Zivko                    Yes                          1           1         1
# Zivko Aeronautics Inc.   Yes                          1           1         1
# Zlin                     No                           2           2         2
# Zlin Aviation s.r.o.     No                           1           1         1
# Zorn                     Yes                          1           1         1
# Zwart                    Yes                          1           1         1
# bourque experimental     Yes                          1           1         1
# de HAVILLAND             No                           1           1         1
# de Havilland             No                         311         311       311
#                          Yes                          1           1         1
# deHAVILLAND              No                           2           2         2
# deHavilland              No                           3           3         3
# unknown                  Yes                          3           3         3
#
#                                         Country  Latitude  Longitude  \
# Make                     Amateur.Built
# 107.5 Flying Corporation Yes                  1         1          1
# 1200                     No                   1         1          1
# 177MF LLC                Yes                  1         1          1
# 1977 COLFER-CHAN         Yes                  1         0          0
# 1ST FTR GP               Yes                  1         0          0
# 2001 MCGIRL              Yes                  1         0          0
# 2003 Nash                Yes                  1         1          1
# 2007 Savage Air LLC      Yes                  1         1          0
# 3XTRIM                   No                   1         1          1
# 67 FLYING DUTCHMAN       Yes                  1         0          0
# 781569 INC               Yes                  1         1          1
# 85 MANISTA               Yes                  1         0          0
# A Pair of Jacks          Yes                  1         0          0
# A. H. GETTINGS           Yes                  1         0          0
# A. LE FRANCOIS           Yes                  1         0          0
# A. Schleicher GMBH & Co. No                   1         1          1
# AAA Aircraft Leasing     No                   1         1          1
# AARDEMA ROBERT JOHN      Yes                  1         1          1
# AB SPORTINE AVIACIJA     No                   4         3          3
# AB Sportine Aviacija     No                   2         2          2
#                          Yes                  1         1          1
# ABBEY VICTOR             Yes                  1         1          1
# ABBOTT                   Yes                  1         0          0
# ABC                      No                   1         0          0
# ABERNATHY                Yes                  1         0          0
# ABRAMS/NUDING            Yes                  1         0          0
# AC Mfg & Dev't Co        No                   1         1          1
# ACKLAND JEFFREY DEAN     Yes                  1         1          1
# ACRODUSTER               Yes                  1         0          0
# ADAMS                    No                   6         0          0
# ...                                         ...       ...        ...
# ZWICKER MURRAY R         Yes                  1         1          1
# Zacharius                Yes                  1         0          0
# Zaverton Elmer           Yes                  1         1          1
# Zawada                   Yes                  1         1          1
# Zdybel                   Yes                  1         0          0
# Zeidler                  Yes                  1         0          0
# Zeidman                  Yes                  1         1          1
# Zenair                   No                   5         2          2
#                          Yes                  7         4          4
# Zenith                   Yes                  2         2          2
# Zhuhai Helicopter Co.    Yes                  1         0          0
# Zidek                    Yes                  1         1          1
# Zielke                   Yes                  1         0          0
# Ziermann                 Yes                  1         1          1
# Zilz                     Yes                  1         1          1
# Zimmerman                Yes                  2         1          1
# Zito                     Yes                  1         0          0
# Zivko                    Yes                  1         1          1
# Zivko Aeronautics Inc.   Yes                  1         1          1
# Zlin                     No                   2         0          0
# Zlin Aviation s.r.o.     No                   1         1          1
# Zorn                     Yes                  1         1          1
# Zwart                    Yes                  1         0          0
# bourque experimental     Yes                  1         0          0
# de HAVILLAND             No                   1         1          1
# de Havilland             No                 308        79         79
#                          Yes                  1         0          0
# deHAVILLAND              No                   2         2          2
# deHavilland              No                   3         3          3
# unknown                  Yes                  3         3          3
#
#                                         Airport.Code  Airport.Name  ...  \
# Make                     Amateur.Built                              ...
# 107.5 Flying Corporation Yes                       1             1  ...
# 1200                     No                        0             0  ...
# 177MF LLC                Yes                       0             0  ...
# 1977 COLFER-CHAN         Yes                       1             1  ...
# 1ST FTR GP               Yes                       0             0  ...
# 2001 MCGIRL              Yes                       1             1  ...
# 2003 Nash                Yes                       0             0  ...
# 2007 Savage Air LLC      Yes                       1             1  ...
# 3XTRIM                   No                        0             0  ...
# 67 FLYING DUTCHMAN       Yes                       0             0  ...
# 781569 INC               Yes                       1             1  ...
# 85 MANISTA               Yes                       0             0  ...
# A Pair of Jacks          Yes                       0             0  ...
# A. H. GETTINGS           Yes                       1             1  ...
# A. LE FRANCOIS           Yes                       1             1  ...
# A. Schleicher GMBH & Co. No                        1             1  ...
# AAA Aircraft Leasing     No                        0             0  ...
# AARDEMA ROBERT JOHN      Yes                       1             1  ...
# AB SPORTINE AVIACIJA     No                        3             4  ...
# AB Sportine Aviacija     No                        0             0  ...
#                          Yes                       0             0  ...
# ABBEY VICTOR             Yes                       1             1  ...
# ABBOTT                   Yes                       0             1  ...
# ABC                      No                        0             0  ...
# ABERNATHY                Yes                       1             1  ...
# ABRAMS/NUDING            Yes                       0             0  ...
# AC Mfg & Dev't Co        No                        1             1  ...
# ACKLAND JEFFREY DEAN     Yes                       1             1  ...
# ACRODUSTER               Yes                       1             1  ...
# ADAMS                    No                        0             0  ...
# ...                                              ...           ...  ...
# ZWICKER MURRAY R         Yes                       0             0  ...
# Zacharius                Yes                       0             0  ...
# Zaverton Elmer           Yes                       0             0  ...
# Zawada                   Yes                       0             0  ...
# Zdybel                   Yes                       1             1  ...
# Zeidler                  Yes                       1             1  ...
# Zeidman                  Yes                       0             0  ...
# Zenair                   No                        4             4  ...
#                          Yes                       5             5  ...
# Zenith                   Yes                       2             2  ...
# Zhuhai Helicopter Co.    Yes                       0             0  ...
# Zidek                    Yes                       0             0  ...
# Zielke                   Yes                       0             0  ...
# Ziermann                 Yes                       0             0  ...
# Zilz                     Yes                       0             0  ...
# Zimmerman                Yes                       2             2  ...
# Zito                     Yes                       1             1  ...
# Zivko                    Yes                       1             1  ...
# Zivko Aeronautics Inc.   Yes                       0             0  ...
# Zlin                     No                        1             0  ...
# Zlin Aviation s.r.o.     No                        0             0  ...
# Zorn                     Yes                       0             0  ...
# Zwart                    Yes                       1             1  ...
# bourque experimental     Yes                       1             1  ...
# de HAVILLAND             No                        0             0  ...
# de Havilland             No                      129           145  ...
#                          Yes                       0             0  ...
# deHAVILLAND              No                        0             0  ...
# deHavilland              No                        2             2  ...
# unknown                  Yes                       1             2  ...
#
#                                         Total.Uninjured  Weather.Condition  \
# Make                     Amateur.Built
# 107.5 Flying Corporation Yes                          0                  1
# 1200                     No                           0                  1
# 177MF LLC                Yes                          0                  1
# 1977 COLFER-CHAN         Yes                          0                  1
# 1ST FTR GP               Yes                          1                  1
# 2001 MCGIRL              Yes                          0                  1
# 2003 Nash                Yes                          0                  1
# 2007 Savage Air LLC      Yes                          1                  1
# 3XTRIM                   No                           0                  0
# 67 FLYING DUTCHMAN       Yes                          1                  1
# 781569 INC               Yes                          0                  1
# 85 MANISTA               Yes                          1                  1
# A Pair of Jacks          Yes                          0                  1
# A. H. GETTINGS           Yes                          1                  1
# A. LE FRANCOIS           Yes                          1                  1
# A. Schleicher GMBH & Co. No                           0                  1
# AAA Aircraft Leasing     No                           0                  1
# AARDEMA ROBERT JOHN      Yes                          1                  1
# AB SPORTINE AVIACIJA     No                           2                  4
# AB Sportine Aviacija     No                           1                  2
#                          Yes                          1                  1
# ABBEY VICTOR             Yes                          0                  1
# ABBOTT                   Yes                          1                  1
# ABC                      No                           1                  1
# ABERNATHY                Yes                          1                  1
# ABRAMS/NUDING            Yes                          1                  1
# AC Mfg & Dev't Co        No                           1                  1
# ACKLAND JEFFREY DEAN     Yes                          1                  1
# ACRODUSTER               Yes                          1                  1
# ADAMS                    No                           6                  6
# ...                                                 ...                ...
# ZWICKER MURRAY R         Yes                          1                  1
# Zacharius                Yes                          1                  1
# Zaverton Elmer           Yes                          0                  1
# Zawada                   Yes                          0                  1
# Zdybel                   Yes                          1                  1
# Zeidler                  Yes                          1                  1
# Zeidman                  Yes                          1                  1
# Zenair                   No                           4                  5
#                          Yes                          6                  7
# Zenith                   Yes                          1                  2
# Zhuhai Helicopter Co.    Yes                          0                  1
# Zidek                    Yes                          0                  1
# Zielke                   Yes                          1                  1
# Ziermann                 Yes                          0                  1
# Zilz                     Yes                          1                  1
# Zimmerman                Yes                          2                  2
# Zito                     Yes                          1                  1
# Zivko                    Yes                          0                  1
# Zivko Aeronautics Inc.   Yes                          0                  1
# Zlin                     No                           0                  0
# Zlin Aviation s.r.o.     No                           0                  1
# Zorn                     Yes                          0                  1
# Zwart                    Yes                          1                  1
# bourque experimental     Yes                          1                  1
# de HAVILLAND             No                           1                  1
# de Havilland             No                         289                309
#                          Yes                          1                  1
# deHAVILLAND              No                           2                  2
# deHavilland              No                           3                  3
# unknown                  Yes                          0                  3
#
#                                         Broad.Phase.of.Flight  Report.Status  \
# Make                     Amateur.Built
# 107.5 Flying Corporation Yes                                0              1
# 1200                     No                                 1              1
# 177MF LLC                Yes                                1              1
# 1977 COLFER-CHAN         Yes                                1              1
# 1ST FTR GP               Yes                                1              1
# 2001 MCGIRL              Yes                                1              1
# 2003 Nash                Yes                                1              1
# 2007 Savage Air LLC      Yes                                1              1
# 3XTRIM                   No                                 0              1
# 67 FLYING DUTCHMAN       Yes                                1              1
# 781569 INC               Yes                                1              1
# 85 MANISTA               Yes                                1              1
# A Pair of Jacks          Yes                                1              1
# A. H. GETTINGS           Yes                                1              1
# A. LE FRANCOIS           Yes                                1              1
# A. Schleicher GMBH & Co. No                                 0              1
# AAA Aircraft Leasing     No                                 1              1
# AARDEMA ROBERT JOHN      Yes                                1              1
# AB SPORTINE AVIACIJA     No                                 4              4
# AB Sportine Aviacija     No                                 1              2
#                          Yes                                1              1
# ABBEY VICTOR             Yes                                1              1
# ABBOTT                   Yes                                1              1
# ABC                      No                                 0              1
# ABERNATHY                Yes                                1              1
# ABRAMS/NUDING            Yes                                1              1
# AC Mfg & Dev't Co        No                                 1              1
# ACKLAND JEFFREY DEAN     Yes                                1              1
# ACRODUSTER               Yes                                1              1
# ADAMS                    No                                 6              6
# ...                                                       ...            ...
# ZWICKER MURRAY R         Yes                                1              1
# Zacharius                Yes                                1              1
# Zaverton Elmer           Yes                                1              1
# Zawada                   Yes                                1              1
# Zdybel                   Yes                                1              1
# Zeidler                  Yes                                1              1
# Zeidman                  Yes                                1              1
# Zenair                   No                                 4              5
#                          Yes                                6              7
# Zenith                   Yes                                1              2
# Zhuhai Helicopter Co.    Yes                                0              1
# Zidek                    Yes                                1              1
# Zielke                   Yes                                1              1
# Ziermann                 Yes                                0              1
# Zilz                     Yes                                1              1
# Zimmerman                Yes                                2              2
# Zito                     Yes                                1              1
# Zivko                    Yes                                1              1
# Zivko Aeronautics Inc.   Yes                                1              1
# Zlin                     No                                 0              2
# Zlin Aviation s.r.o.     No                                 1              1
# Zorn                     Yes                                1              1
# Zwart                    Yes                                1              1
# bourque experimental     Yes                                1              1
# de HAVILLAND             No                                 1              1
# de Havilland             No                               288            311
#                          Yes                                0              1
# deHAVILLAND              No                                 2              2
# deHavilland              No                                 3              3
# unknown                  Yes                                3              3
#
#                                         Publication.Date  Year  Month  Day  \
# Make                     Amateur.Built
# 107.5 Flying Corporation Yes                           1     1      1    1
# 1200                     No                            1     1      1    1
# 177MF LLC                Yes                           1     1      1    1
# 1977 COLFER-CHAN         Yes                           1     1      1    1
# 1ST FTR GP               Yes                           1     1      1    1
# 2001 MCGIRL              Yes                           1     1      1    1
# 2003 Nash                Yes                           1     1      1    1
# 2007 Savage Air LLC      Yes                           1     1      1    1
# 3XTRIM                   No                            0     1      1    1
# 67 FLYING DUTCHMAN       Yes                           1     1      1    1
# 781569 INC               Yes                           1     1      1    1
# 85 MANISTA               Yes                           1     1      1    1
# A Pair of Jacks          Yes                           1     1      1    1
# A. H. GETTINGS           Yes                           1     1      1    1
# A. LE FRANCOIS           Yes                           1     1      1    1
# A. Schleicher GMBH & Co. No                            1     1      1    1
# AAA Aircraft Leasing     No                            1     1      1    1
# AARDEMA ROBERT JOHN      Yes                           1     1      1    1
# AB SPORTINE AVIACIJA     No                            4     4      4    4
# AB Sportine Aviacija     No                            2     2      2    2
#                          Yes                           1     1      1    1
# ABBEY VICTOR             Yes                           1     1      1    1
# ABBOTT                   Yes                           1     1      1    1
# ABC                      No                            1     1      1    1
# ABERNATHY                Yes                           1     1      1    1
# ABRAMS/NUDING            Yes                           1     1      1    1
# AC Mfg & Dev't Co        No                            1     1      1    1
# ACKLAND JEFFREY DEAN     Yes                           1     1      1    1
# ACRODUSTER               Yes                           1     1      1    1
# ADAMS                    No                            2     6      6    6
# ...                                                  ...   ...    ...  ...
# ZWICKER MURRAY R         Yes                           1     1      1    1
# Zacharius                Yes                           1     1      1    1
# Zaverton Elmer           Yes                           1     1      1    1
# Zawada                   Yes                           1     1      1    1
# Zdybel                   Yes                           1     1      1    1
# Zeidler                  Yes                           1     1      1    1
# Zeidman                  Yes                           1     1      1    1
# Zenair                   No                            5     5      5    5
#                          Yes                           7     7      7    7
# Zenith                   Yes                           2     2      2    2
# Zhuhai Helicopter Co.    Yes                           0     1      1    1
# Zidek                    Yes                           1     1      1    1
# Zielke                   Yes                           1     1      1    1
# Ziermann                 Yes                           1     1      1    1
# Zilz                     Yes                           1     1      1    1
# Zimmerman                Yes                           2     2      2    2
# Zito                     Yes                           1     1      1    1
# Zivko                    Yes                           1     1      1    1
# Zivko Aeronautics Inc.   Yes                           1     1      1    1
# Zlin                     No                            2     2      2    2
# Zlin Aviation s.r.o.     No                            1     1      1    1
# Zorn                     Yes                           1     1      1    1
# Zwart                    Yes                           1     1      1    1
# bourque experimental     Yes                           1     1      1    1
# de HAVILLAND             No                            1     1      1    1
# de Havilland             No                          257   311    311  311
#                          Yes                           1     1      1    1
# deHAVILLAND              No                            2     2      2    2
# deHavilland              No                            3     3      3    3
# unknown                  Yes                           3     3      3    3
#
#                                         AmateurBuilt  index
# Make                     Amateur.Built
# 107.5 Flying Corporation Yes                       1      1
# 1200                     No                        1      1
# 177MF LLC                Yes                       1      1
# 1977 COLFER-CHAN         Yes                       1      1
# 1ST FTR GP               Yes                       1      1
# 2001 MCGIRL              Yes                       1      1
# 2003 Nash                Yes                       1      1
# 2007 Savage Air LLC      Yes                       1      1
# 3XTRIM                   No                        1      1
# 67 FLYING DUTCHMAN       Yes                       1      1
# 781569 INC               Yes                       1      1
# 85 MANISTA               Yes                       1      1
# A Pair of Jacks          Yes                       1      1
# A. H. GETTINGS           Yes                       1      1
# A. LE FRANCOIS           Yes                       1      1
# A. Schleicher GMBH & Co. No                        1      1
# AAA Aircraft Leasing     No                        1      1
# AARDEMA ROBERT JOHN      Yes                       1      1
# AB SPORTINE AVIACIJA     No                        4      4
# AB Sportine Aviacija     No                        2      2
#                          Yes                       1      1
# ABBEY VICTOR             Yes                       1      1
# ABBOTT                   Yes                       1      1
# ABC                      No                        1      1
# ABERNATHY                Yes                       1      1
# ABRAMS/NUDING            Yes                       1      1
# AC Mfg & Dev't Co        No                        1      1
# ACKLAND JEFFREY DEAN     Yes                       1      1
# ACRODUSTER               Yes                       1      1
# ADAMS                    No                        6      6
# ...                                              ...    ...
# ZWICKER MURRAY R         Yes                       1      1
# Zacharius                Yes                       1      1
# Zaverton Elmer           Yes                       1      1
# Zawada                   Yes                       1      1
# Zdybel                   Yes                       1      1
# Zeidler                  Yes                       1      1
# Zeidman                  Yes                       1      1
# Zenair                   No                        5      5
#                          Yes                       7      7
# Zenith                   Yes                       2      2
# Zhuhai Helicopter Co.    Yes                       1      1
# Zidek                    Yes                       1      1
# Zielke                   Yes                       1      1
# Ziermann                 Yes                       1      1
# Zilz                     Yes                       1      1
# Zimmerman                Yes                       2      2
# Zito                     Yes                       1      1
# Zivko                    Yes                       1      1
# Zivko Aeronautics Inc.   Yes                       1      1
# Zlin                     No                        2      2
# Zlin Aviation s.r.o.     No                        1      1
# Zorn                     Yes                       1      1
# Zwart                    Yes                       1      1
# bourque experimental     Yes                       1      1
# de HAVILLAND             No                        1      1
# de Havilland             No                      311    311
#                          Yes                       1      1
# deHAVILLAND              No                        2      2
# deHavilland              No                        3      3
# unknown                  Yes                       3      3
#
# [8135 rows x 34 columns]

# %%
producers = [x for x in df['Weather.Condition'][df['Aircraft.Damage']== 'No'].unique() ]
amateurs  = [x for x in df['Weather.Condition'][df['Aircraft.Damage']== 'Yes'].unique() ]

# -----------------------------------------------
# Function that fixes the null in amateur.built
def fix_amateur_built(ab, m):
    if type(ab) == str:
        return ab
    else:
        if m in producers:
            return 'No'
        else:
            return 'Yes'
# Fix for Amateur.Built field      
am_built = df.apply(lambda x: fix_amateur_built(x['Amateur.Built'], x['Make']), axis=1)
df = df.assign(AmateurBuilt = am_built, index=df.index)

# %%
print(df.groupby(['Make','Model']).count())
# Out:
#                                                Event.Id  Investigation.Type  \
# Make                     Model
# 107.5 Flying Corporation One Design DR 107            1                   1
# 1200                     G103                         1                   1
# 177MF LLC                PITTS MODEL 12               1                   1
# 1977 COLFER-CHAN         STEEN SKYBOLT                1                   1
# 1ST FTR GP               FOCKE-WULF 190               1                   1
# 2000 McCoy               Genesis                      1                   1
# 2001 MCGIRL              QUESTAIR VENTURE             1                   1
# 2003 Nash                Kitfox II                    1                   1
# 2007 Savage Air LLC      EPIC LT                      1                   1
# 3XTRIM                   450 ULTRA                    1                   1
# 67 FLYING DUTCHMAN       D1/LFD-13                    1                   1
# 781569 INC               FX 210                       1                   1
# 85 MANISTA               KB-2                         1                   1
# A Pair of Jacks          RV-6A                        1                   1
# A. H. GETTINGS           GLASSAIR SH2                 1                   1
# A. LE FRANCOIS           RANS S-7                     1                   1
# A. Schleicher GMBH & Co. ASW 27-18                    1                   1
# AAA Aircraft Leasing     192                          1                   1
# AARDEMA ROBERT JOHN      1 AARDEMA RAG WNG SP         1                   1
# AB SPORTINE AVIACIJA     GENESIS 2                    2                   2
#                          LAK 17                       1                   1
#                          LAK-17A                      1                   1
# AB Sportine Aviacija     Genesis 2                    3                   3
# ABBEY VICTOR             RV9-A                        1                   1
# ABBOTT                   GYROPLANE                    1                   1
# ABC                      ABC 60 PLUS                  1                   1
# ABERNATHY                LONG-EZ                      1                   1
# ABRAMS/NUDING            QUICKIE Q2                   1                   1
# AC Mfg & Dev't Co        CH 2000                      1                   1
# ACKLAND JEFFREY DEAN     SH 3R                        1                   1
# ...                                                 ...                 ...
# de Havilland             DHC-7-102                    3                   3
#                          DHC-7-103                    1                   1
#                          DHC-8                        4                   4
#                          DHC-8-100                    1                   1
#                          DHC-8-101                    2                   2
#                          DHC-8-101/102                1                   1
#                          DHC-8-102                   10                  10
#                          DHC-8-202                    2                   2
#                          DHC-8-311                    3                   3
#                          DHC-8-4002                   1                   1
#                          DHC-94 Moth Minor            1                   1
#                          DHC-II                       1                   1
#                          DHC2                         2                   2
#                          DHC2-MK I                    1                   1
#                          DHC6-300                     1                   1
#                          DHC6-33                      1                   1
#                          DRAGONFLY DH-90              1                   1
#                          Dash 8-100                   1                   1
#                          GIPSY MOTH DH.60G            1                   1
#                          OTTER DHC-3                  1                   1
#                          SHD-6                        2                   2
#                          TIGER MOTH DH 82A            2                   2
#                          TIGER MOTH DH82A             1                   1
#                          U-6A                         2                   2
#                          U6A                          1                   1
# deHAVILLAND              DHC-2                        2                   2
# deHavilland              DHC-2                        3                   3
# unknown                  Avid Flyer                   1                   1
#                          kit                          1                   1
#                          unknown                      1                   1
#
#                                                Accident.Number  Event.Date  \
# Make                     Model
# 107.5 Flying Corporation One Design DR 107                   1           1
# 1200                     G103                                1           1
# 177MF LLC                PITTS MODEL 12                      1           1
# 1977 COLFER-CHAN         STEEN SKYBOLT                       1           1
# 1ST FTR GP               FOCKE-WULF 190                      1           1
# 2000 McCoy               Genesis                             1           1
# 2001 MCGIRL              QUESTAIR VENTURE                    1           1
# 2003 Nash                Kitfox II                           1           1
# 2007 Savage Air LLC      EPIC LT                             1           1
# 3XTRIM                   450 ULTRA                           1           1
# 67 FLYING DUTCHMAN       D1/LFD-13                           1           1
# 781569 INC               FX 210                              1           1
# 85 MANISTA               KB-2                                1           1
# A Pair of Jacks          RV-6A                               1           1
# A. H. GETTINGS           GLASSAIR SH2                        1           1
# A. LE FRANCOIS           RANS S-7                            1           1
# A. Schleicher GMBH & Co. ASW 27-18                           1           1
# AAA Aircraft Leasing     192                                 1           1
# AARDEMA ROBERT JOHN      1 AARDEMA RAG WNG SP                1           1
# AB SPORTINE AVIACIJA     GENESIS 2                           2           2
#                          LAK 17                              1           1
#                          LAK-17A                             1           1
# AB Sportine Aviacija     Genesis 2                           3           3
# ABBEY VICTOR             RV9-A                               1           1
# ABBOTT                   GYROPLANE                           1           1
# ABC                      ABC 60 PLUS                         1           1
# ABERNATHY                LONG-EZ                             1           1
# ABRAMS/NUDING            QUICKIE Q2                          1           1
# AC Mfg & Dev't Co        CH 2000                             1           1
# ACKLAND JEFFREY DEAN     SH 3R                               1           1
# ...                                                        ...         ...
# de Havilland             DHC-7-102                           3           3
#                          DHC-7-103                           1           1
#                          DHC-8                               4           4
#                          DHC-8-100                           1           1
#                          DHC-8-101                           2           2
#                          DHC-8-101/102                       1           1
#                          DHC-8-102                          10          10
#                          DHC-8-202                           2           2
#                          DHC-8-311                           3           3
#                          DHC-8-4002                          1           1
#                          DHC-94 Moth Minor                   1           1
#                          DHC-II                              1           1
#                          DHC2                                2           2
#                          DHC2-MK I                           1           1
#                          DHC6-300                            1           1
#                          DHC6-33                             1           1
#                          DRAGONFLY DH-90                     1           1
#                          Dash 8-100                          1           1
#                          GIPSY MOTH DH.60G                   1           1
#                          OTTER DHC-3                         1           1
#                          SHD-6                               2           2
#                          TIGER MOTH DH 82A                   2           2
#                          TIGER MOTH DH82A                    1           1
#                          U-6A                                2           2
#                          U6A                                 1           1
# deHAVILLAND              DHC-2                               2           2
# deHavilland              DHC-2                               3           3
# unknown                  Avid Flyer                          1           1
#                          kit                                 1           1
#                          unknown                             1           1
#
#                                                Location  Country  Latitude  \
# Make                     Model
# 107.5 Flying Corporation One Design DR 107            1        1         1
# 1200                     G103                         1        1         1
# 177MF LLC                PITTS MODEL 12               1        1         1
# 1977 COLFER-CHAN         STEEN SKYBOLT                1        1         0
# 1ST FTR GP               FOCKE-WULF 190               1        1         0
# 2000 McCoy               Genesis                      1        1         0
# 2001 MCGIRL              QUESTAIR VENTURE             1        1         0
# 2003 Nash                Kitfox II                    1        1         1
# 2007 Savage Air LLC      EPIC LT                      1        1         1
# 3XTRIM                   450 ULTRA                    1        1         1
# 67 FLYING DUTCHMAN       D1/LFD-13                    1        1         0
# 781569 INC               FX 210                       1        1         1
# 85 MANISTA               KB-2                         1        1         0
# A Pair of Jacks          RV-6A                        1        1         0
# A. H. GETTINGS           GLASSAIR SH2                 1        1         0
# A. LE FRANCOIS           RANS S-7                     1        1         0
# A. Schleicher GMBH & Co. ASW 27-18                    1        1         1
# AAA Aircraft Leasing     192                          1        1         1
# AARDEMA ROBERT JOHN      1 AARDEMA RAG WNG SP         1        1         1
# AB SPORTINE AVIACIJA     GENESIS 2                    2        2         1
#                          LAK 17                       1        1         1
#                          LAK-17A                      1        1         1
# AB Sportine Aviacija     Genesis 2                    3        3         3
# ABBEY VICTOR             RV9-A                        1        1         1
# ABBOTT                   GYROPLANE                    1        1         0
# ABC                      ABC 60 PLUS                  1        1         0
# ABERNATHY                LONG-EZ                      1        1         0
# ABRAMS/NUDING            QUICKIE Q2                   1        1         0
# AC Mfg & Dev't Co        CH 2000                      1        1         1
# ACKLAND JEFFREY DEAN     SH 3R                        1        1         1
# ...                                                 ...      ...       ...
# de Havilland             DHC-7-102                    3        3         0
#                          DHC-7-103                    1        1         0
#                          DHC-8                        4        4         1
#                          DHC-8-100                    1        1         0
#                          DHC-8-101                    2        2         0
#                          DHC-8-101/102                1        1         0
#                          DHC-8-102                   10       10         1
#                          DHC-8-202                    2        2         2
#                          DHC-8-311                    3        3         0
#                          DHC-8-4002                   1        1         0
#                          DHC-94 Moth Minor            1        1         0
#                          DHC-II                       1        1         0
#                          DHC2                         2        2         0
#                          DHC2-MK I                    1        1         0
#                          DHC6-300                     1        1         0
#                          DHC6-33                      1        1         1
#                          DRAGONFLY DH-90              1        1         0
#                          Dash 8-100                   1        1         0
#                          GIPSY MOTH DH.60G            1        1         0
#                          OTTER DHC-3                  1        1         0
#                          SHD-6                        2        2         0
#                          TIGER MOTH DH 82A            2        2         0
#                          TIGER MOTH DH82A             1        1         0
#                          U-6A                         2        2         0
#                          U6A                          1        1         0
# deHAVILLAND              DHC-2                        2        2         2
# deHavilland              DHC-2                        3        3         3
# unknown                  Avid Flyer                   1        1         1
#                          kit                          1        1         1
#                          unknown                      1        1         1
#
#                                                Longitude  Airport.Code  \
# Make                     Model
# 107.5 Flying Corporation One Design DR 107             1             1
# 1200                     G103                          1             0
# 177MF LLC                PITTS MODEL 12                1             0
# 1977 COLFER-CHAN         STEEN SKYBOLT                 0             1
# 1ST FTR GP               FOCKE-WULF 190                0             0
# 2000 McCoy               Genesis                       0             0
# 2001 MCGIRL              QUESTAIR VENTURE              0             1
# 2003 Nash                Kitfox II                     1             0
# 2007 Savage Air LLC      EPIC LT                       0             1
# 3XTRIM                   450 ULTRA                     1             0
# 67 FLYING DUTCHMAN       D1/LFD-13                     0             0
# 781569 INC               FX 210                        1             1
# 85 MANISTA               KB-2                          0             0
# A Pair of Jacks          RV-6A                         0             0
# A. H. GETTINGS           GLASSAIR SH2                  0             1
# A. LE FRANCOIS           RANS S-7                      0             1
# A. Schleicher GMBH & Co. ASW 27-18                     1             1
# AAA Aircraft Leasing     192                           1             0
# AARDEMA ROBERT JOHN      1 AARDEMA RAG WNG SP          1             1
# AB SPORTINE AVIACIJA     GENESIS 2                     1             1
#                          LAK 17                        1             1
#                          LAK-17A                       1             1
# AB Sportine Aviacija     Genesis 2                     3             0
# ABBEY VICTOR             RV9-A                         1             1
# ABBOTT                   GYROPLANE                     0             0
# ABC                      ABC 60 PLUS                   0             0
# ABERNATHY                LONG-EZ                       0             1
# ABRAMS/NUDING            QUICKIE Q2                    0             0
# AC Mfg & Dev't Co        CH 2000                       1             1
# ACKLAND JEFFREY DEAN     SH 3R                         1             1
# ...                                                  ...           ...
# de Havilland             DHC-7-102                     0             1
#                          DHC-7-103                     0             0
#                          DHC-8                         1             4
#                          DHC-8-100                     0             0
#                          DHC-8-101                     0             2
#                          DHC-8-101/102                 0             0
#                          DHC-8-102                     1             7
#                          DHC-8-202                     2             1
#                          DHC-8-311                     0             2
#                          DHC-8-4002                    0             0
#                          DHC-94 Moth Minor             0             0
#                          DHC-II                        0             1
#                          DHC2                          0             1
#                          DHC2-MK I                     0             1
#                          DHC6-300                      0             1
#                          DHC6-33                       1             1
#                          DRAGONFLY DH-90               0             1
#                          Dash 8-100                    0             1
#                          GIPSY MOTH DH.60G             0             1
#                          OTTER DHC-3                   0             0
#                          SHD-6                         0             2
#                          TIGER MOTH DH 82A             0             1
#                          TIGER MOTH DH82A              0             1
#                          U-6A                          0             1
#                          U6A                           0             0
# deHAVILLAND              DHC-2                         2             0
# deHavilland              DHC-2                         3             2
# unknown                  Avid Flyer                    1             1
#                          kit                           1             0
#                          unknown                       1             0
#
#                                                Airport.Name  ...  \
# Make                     Model                               ...
# 107.5 Flying Corporation One Design DR 107                1  ...
# 1200                     G103                             0  ...
# 177MF LLC                PITTS MODEL 12                   0  ...
# 1977 COLFER-CHAN         STEEN SKYBOLT                    1  ...
# 1ST FTR GP               FOCKE-WULF 190                   0  ...
# 2000 McCoy               Genesis                          0  ...
# 2001 MCGIRL              QUESTAIR VENTURE                 1  ...
# 2003 Nash                Kitfox II                        0  ...
# 2007 Savage Air LLC      EPIC LT                          1  ...
# 3XTRIM                   450 ULTRA                        0  ...
# 67 FLYING DUTCHMAN       D1/LFD-13                        0  ...
# 781569 INC               FX 210                           1  ...
# 85 MANISTA               KB-2                             0  ...
# A Pair of Jacks          RV-6A                            0  ...
# A. H. GETTINGS           GLASSAIR SH2                     1  ...
# A. LE FRANCOIS           RANS S-7                         1  ...
# A. Schleicher GMBH & Co. ASW 27-18                        1  ...
# AAA Aircraft Leasing     192                              0  ...
# AARDEMA ROBERT JOHN      1 AARDEMA RAG WNG SP             1  ...
# AB SPORTINE AVIACIJA     GENESIS 2                        2  ...
#                          LAK 17                           1  ...
#                          LAK-17A                          1  ...
# AB Sportine Aviacija     Genesis 2                        0  ...
# ABBEY VICTOR             RV9-A                            1  ...
# ABBOTT                   GYROPLANE                        1  ...
# ABC                      ABC 60 PLUS                      0  ...
# ABERNATHY                LONG-EZ                          1  ...
# ABRAMS/NUDING            QUICKIE Q2                       0  ...
# AC Mfg & Dev't Co        CH 2000                          1  ...
# ACKLAND JEFFREY DEAN     SH 3R                            1  ...
# ...                                                     ...  ...
# de Havilland             DHC-7-102                        1  ...
#                          DHC-7-103                        0  ...
#                          DHC-8                            4  ...
#                          DHC-8-100                        0  ...
#                          DHC-8-101                        2  ...
#                          DHC-8-101/102                    0  ...
#                          DHC-8-102                        7  ...
#                          DHC-8-202                        1  ...
#                          DHC-8-311                        2  ...
#                          DHC-8-4002                       0  ...
#                          DHC-94 Moth Minor                0  ...
#                          DHC-II                           1  ...
#                          DHC2                             2  ...
#                          DHC2-MK I                        1  ...
#                          DHC6-300                         1  ...
#                          DHC6-33                          1  ...
#                          DRAGONFLY DH-90                  1  ...
#                          Dash 8-100                       1  ...
#                          GIPSY MOTH DH.60G                1  ...
#                          OTTER DHC-3                      1  ...
#                          SHD-6                            2  ...
#                          TIGER MOTH DH 82A                1  ...
#                          TIGER MOTH DH82A                 1  ...
#                          U-6A                             1  ...
#                          U6A                              0  ...
# deHAVILLAND              DHC-2                            0  ...
# deHavilland              DHC-2                            2  ...
# unknown                  Avid Flyer                       1  ...
#                          kit                              0  ...
#                          unknown                          1  ...
#
#                                                Purpose.of.Flight  Air.Carrier  \
# Make                     Model
# 107.5 Flying Corporation One Design DR 107                     1            0
# 1200                     G103                                  1            0
# 177MF LLC                PITTS MODEL 12                        1            0
# 1977 COLFER-CHAN         STEEN SKYBOLT                         1            0
# 1ST FTR GP               FOCKE-WULF 190                        1            0
# 2000 McCoy               Genesis                               1            0
# 2001 MCGIRL              QUESTAIR VENTURE                      1            0
# 2003 Nash                Kitfox II                             1            0
# 2007 Savage Air LLC      EPIC LT                               1            0
# 3XTRIM                   450 ULTRA                             0            0
# 67 FLYING DUTCHMAN       D1/LFD-13                             1            0
# 781569 INC               FX 210                                1            0
# 85 MANISTA               KB-2                                  1            0
# A Pair of Jacks          RV-6A                                 1            0
# A. H. GETTINGS           GLASSAIR SH2                          1            0
# A. LE FRANCOIS           RANS S-7                              1            0
# A. Schleicher GMBH & Co. ASW 27-18                             1            0
# AAA Aircraft Leasing     192                                   1            0
# AARDEMA ROBERT JOHN      1 AARDEMA RAG WNG SP                  1            0
# AB SPORTINE AVIACIJA     GENESIS 2                             2            0
#                          LAK 17                                1            0
#                          LAK-17A                               1            0
# AB Sportine Aviacija     Genesis 2                             3            0
# ABBEY VICTOR             RV9-A                                 1            0
# ABBOTT                   GYROPLANE                             1            0
# ABC                      ABC 60 PLUS                           1            0
# ABERNATHY                LONG-EZ                               1            0
# ABRAMS/NUDING            QUICKIE Q2                            1            0
# AC Mfg & Dev't Co        CH 2000                               1            0
# ACKLAND JEFFREY DEAN     SH 3R                                 1            0
# ...                                                          ...          ...
# de Havilland             DHC-7-102                             3            2
#                          DHC-7-103                             1            1
#                          DHC-8                                 3            4
#                          DHC-8-100                             1            1
#                          DHC-8-101                             2            2
#                          DHC-8-101/102                         1            1
#                          DHC-8-102                             7           10
#                          DHC-8-202                             0            1
#                          DHC-8-311                             3            3
#                          DHC-8-4002                            0            0
#                          DHC-94 Moth Minor                     1            0
#                          DHC-II                                1            1
#                          DHC2                                  2            1
#                          DHC2-MK I                             1            1
#                          DHC6-300                              1            1
#                          DHC6-33                               0            0
#                          DRAGONFLY DH-90                       1            0
#                          Dash 8-100                            0            1
#                          GIPSY MOTH DH.60G                     1            0
#                          OTTER DHC-3                           1            0
#                          SHD-6                                 2            2
#                          TIGER MOTH DH 82A                     2            0
#                          TIGER MOTH DH82A                      1            0
#                          U-6A                                  2            0
#                          U6A                                   1            0
# deHAVILLAND              DHC-2                                 0            0
# deHavilland              DHC-2                                 3            0
# unknown                  Avid Flyer                            1            0
#                          kit                                   1            0
#                          unknown                               1            0
#
#                                                Total.Fatal.Injuries  \
# Make                     Model
# 107.5 Flying Corporation One Design DR 107                        1
# 1200                     G103                                     0
# 177MF LLC                PITTS MODEL 12                           0
# 1977 COLFER-CHAN         STEEN SKYBOLT                            0
# 1ST FTR GP               FOCKE-WULF 190                           1
# 2000 McCoy               Genesis                                  1
# 2001 MCGIRL              QUESTAIR VENTURE                         0
# 2003 Nash                Kitfox II                                0
# 2007 Savage Air LLC      EPIC LT                                  0
# 3XTRIM                   450 ULTRA                                1
# 67 FLYING DUTCHMAN       D1/LFD-13                                1
# 781569 INC               FX 210                                   0
# 85 MANISTA               KB-2                                     1
# A Pair of Jacks          RV-6A                                    0
# A. H. GETTINGS           GLASSAIR SH2                             1
# A. LE FRANCOIS           RANS S-7                                 1
# A. Schleicher GMBH & Co. ASW 27-18                                0
# AAA Aircraft Leasing     192                                      1
# AARDEMA ROBERT JOHN      1 AARDEMA RAG WNG SP                     0
# AB SPORTINE AVIACIJA     GENESIS 2                                1
#                          LAK 17                                   0
#                          LAK-17A                                  0
# AB Sportine Aviacija     Genesis 2                                0
# ABBEY VICTOR             RV9-A                                    0
# ABBOTT                   GYROPLANE                                1
# ABC                      ABC 60 PLUS                              1
# ABERNATHY                LONG-EZ                                  1
# ABRAMS/NUDING            QUICKIE Q2                               1
# AC Mfg & Dev't Co        CH 2000                                  0
# ACKLAND JEFFREY DEAN     SH 3R                                    0
# ...                                                             ...
# de Havilland             DHC-7-102                                3
#                          DHC-7-103                                1
#                          DHC-8                                    3
#                          DHC-8-100                                1
#                          DHC-8-101                                2
#                          DHC-8-101/102                            1
#                          DHC-8-102                                7
#                          DHC-8-202                                0
#                          DHC-8-311                                3
#                          DHC-8-4002                               0
#                          DHC-94 Moth Minor                        0
#                          DHC-II                                   1
#                          DHC2                                     2
#                          DHC2-MK I                                1
#                          DHC6-300                                 1
#                          DHC6-33                                  1
#                          DRAGONFLY DH-90                          1
#                          Dash 8-100                               1
#                          GIPSY MOTH DH.60G                        1
#                          OTTER DHC-3                              1
#                          SHD-6                                    2
#                          TIGER MOTH DH 82A                        2
#                          TIGER MOTH DH82A                         1
#                          U-6A                                     2
#                          U6A                                      1
# deHAVILLAND              DHC-2                                    0
# deHavilland              DHC-2                                    0
# unknown                  Avid Flyer                               0
#                          kit                                      0
#                          unknown                                  1
#
#                                                Total.Serious.Injuries  \
# Make                     Model
# 107.5 Flying Corporation One Design DR 107                          0
# 1200                     G103                                       1
# 177MF LLC                PITTS MODEL 12                             0
# 1977 COLFER-CHAN         STEEN SKYBOLT                              0
# 1ST FTR GP               FOCKE-WULF 190                             1
# 2000 McCoy               Genesis                                    0
# 2001 MCGIRL              QUESTAIR VENTURE                           1
# 2003 Nash                Kitfox II                                  0
# 2007 Savage Air LLC      EPIC LT                                    0
# 3XTRIM                   450 ULTRA                                  1
# 67 FLYING DUTCHMAN       D1/LFD-13                                  1
# 781569 INC               FX 210                                     0
# 85 MANISTA               KB-2                                       1
# A Pair of Jacks          RV-6A                                      0
# A. H. GETTINGS           GLASSAIR SH2                               1
# A. LE FRANCOIS           RANS S-7                                   1
# A. Schleicher GMBH & Co. ASW 27-18                                  0
# AAA Aircraft Leasing     192                                        0
# AARDEMA ROBERT JOHN      1 AARDEMA RAG WNG SP                       0
# AB SPORTINE AVIACIJA     GENESIS 2                                  1
#                          LAK 17                                     0
#                          LAK-17A                                    1
# AB Sportine Aviacija     Genesis 2                                  1
# ABBEY VICTOR             RV9-A                                      0
# ABBOTT                   GYROPLANE                                  1
# ABC                      ABC 60 PLUS                                1
# ABERNATHY                LONG-EZ                                    1
# ABRAMS/NUDING            QUICKIE Q2                                 1
# AC Mfg & Dev't Co        CH 2000                                    0
# ACKLAND JEFFREY DEAN     SH 3R                                      0
# ...                                                               ...
# de Havilland             DHC-7-102                                  3
#                          DHC-7-103                                  1
#                          DHC-8                                      3
#                          DHC-8-100                                  1
#                          DHC-8-101                                  2
#                          DHC-8-101/102                              1
#                          DHC-8-102                                  7
#                          DHC-8-202                                  1
#                          DHC-8-311                                  3
#                          DHC-8-4002                                 0
#                          DHC-94 Moth Minor                          0
#                          DHC-II                                     1
#                          DHC2                                       2
#                          DHC2-MK I                                  1
#                          DHC6-300                                   1
#                          DHC6-33                                    0
#                          DRAGONFLY DH-90                            1
#                          Dash 8-100                                 0
#                          GIPSY MOTH DH.60G                          1
#                          OTTER DHC-3                                1
#                          SHD-6                                      2
#                          TIGER MOTH DH 82A                          2
#                          TIGER MOTH DH82A                           1
#                          U-6A                                       2
#                          U6A                                        1
# deHAVILLAND              DHC-2                                      0
# deHavilland              DHC-2                                      0
# unknown                  Avid Flyer                                 0
#                          kit                                        1
#                          unknown                                    0
#
#                                                Total.Minor.Injuries  \
# Make                     Model
# 107.5 Flying Corporation One Design DR 107                        0
# 1200                     G103                                     0
# 177MF LLC                PITTS MODEL 12                           1
# 1977 COLFER-CHAN         STEEN SKYBOLT                            1
# 1ST FTR GP               FOCKE-WULF 190                           1
# 2000 McCoy               Genesis                                  0
# 2001 MCGIRL              QUESTAIR VENTURE                         0
# 2003 Nash                Kitfox II                                1
# 2007 Savage Air LLC      EPIC LT                                  0
# 3XTRIM                   450 ULTRA                                0
# 67 FLYING DUTCHMAN       D1/LFD-13                                1
# 781569 INC               FX 210                                   1
# 85 MANISTA               KB-2                                     1
# A Pair of Jacks          RV-6A                                    1
# A. H. GETTINGS           GLASSAIR SH2                             1
# A. LE FRANCOIS           RANS S-7                                 1
# A. Schleicher GMBH & Co. ASW 27-18                                1
# AAA Aircraft Leasing     192                                      0
# AARDEMA ROBERT JOHN      1 AARDEMA RAG WNG SP                     0
# AB SPORTINE AVIACIJA     GENESIS 2                                2
#                          LAK 17                                   0
#                          LAK-17A                                  0
# AB Sportine Aviacija     Genesis 2                                1
# ABBEY VICTOR             RV9-A                                    1
# ABBOTT                   GYROPLANE                                1
# ABC                      ABC 60 PLUS                              1
# ABERNATHY                LONG-EZ                                  1
# ABRAMS/NUDING            QUICKIE Q2                               1
# AC Mfg & Dev't Co        CH 2000                                  0
# ACKLAND JEFFREY DEAN     SH 3R                                    0
# ...                                                             ...
# de Havilland             DHC-7-102                                3
#                          DHC-7-103                                1
#                          DHC-8                                    3
#                          DHC-8-100                                1
#                          DHC-8-101                                2
#                          DHC-8-101/102                            1
#                          DHC-8-102                                7
#                          DHC-8-202                                1
#                          DHC-8-311                                3
#                          DHC-8-4002                               0
#                          DHC-94 Moth Minor                        0
#                          DHC-II                                   1
#                          DHC2                                     2
#                          DHC2-MK I                                1
#                          DHC6-300                                 1
#                          DHC6-33                                  0
#                          DRAGONFLY DH-90                          1
#                          Dash 8-100                               0
#                          GIPSY MOTH DH.60G                        1
#                          OTTER DHC-3                              1
#                          SHD-6                                    2
#                          TIGER MOTH DH 82A                        2
#                          TIGER MOTH DH82A                         1
#                          U-6A                                     2
#                          U6A                                      1
# deHAVILLAND              DHC-2                                    0
# deHavilland              DHC-2                                    0
# unknown                  Avid Flyer                               1
#                          kit                                      0
#                          unknown                                  0
#
#                                                Total.Uninjured  \
# Make                     Model
# 107.5 Flying Corporation One Design DR 107                   0
# 1200                     G103                                0
# 177MF LLC                PITTS MODEL 12                      0
# 1977 COLFER-CHAN         STEEN SKYBOLT                       0
# 1ST FTR GP               FOCKE-WULF 190                      1
# 2000 McCoy               Genesis                             0
# 2001 MCGIRL              QUESTAIR VENTURE                    0
# 2003 Nash                Kitfox II                           0
# 2007 Savage Air LLC      EPIC LT                             1
# 3XTRIM                   450 ULTRA                           0
# 67 FLYING DUTCHMAN       D1/LFD-13                           1
# 781569 INC               FX 210                              0
# 85 MANISTA               KB-2                                1
# A Pair of Jacks          RV-6A                               0
# A. H. GETTINGS           GLASSAIR SH2                        1
# A. LE FRANCOIS           RANS S-7                            1
# A. Schleicher GMBH & Co. ASW 27-18                           0
# AAA Aircraft Leasing     192                                 0
# AARDEMA ROBERT JOHN      1 AARDEMA RAG WNG SP                1
# AB SPORTINE AVIACIJA     GENESIS 2                           1
#                          LAK 17                              1
#                          LAK-17A                             0
# AB Sportine Aviacija     Genesis 2                           2
# ABBEY VICTOR             RV9-A                               0
# ABBOTT                   GYROPLANE                           1
# ABC                      ABC 60 PLUS                         1
# ABERNATHY                LONG-EZ                             1
# ABRAMS/NUDING            QUICKIE Q2                          1
# AC Mfg & Dev't Co        CH 2000                             1
# ACKLAND JEFFREY DEAN     SH 3R                               1
# ...                                                        ...
# de Havilland             DHC-7-102                           3
#                          DHC-7-103                           1
#                          DHC-8                               4
#                          DHC-8-100                           1
#                          DHC-8-101                           2
#                          DHC-8-101/102                       1
#                          DHC-8-102                          10
#                          DHC-8-202                           2
#                          DHC-8-311                           3
#                          DHC-8-4002                          0
#                          DHC-94 Moth Minor                   1
#                          DHC-II                              1
#                          DHC2                                2
#                          DHC2-MK I                           1
#                          DHC6-300                            1
#                          DHC6-33                             0
#                          DRAGONFLY DH-90                     1
#                          Dash 8-100                          1
#                          GIPSY MOTH DH.60G                   1
#                          OTTER DHC-3                         1
#                          SHD-6                               2
#                          TIGER MOTH DH 82A                   2
#                          TIGER MOTH DH82A                    1
#                          U-6A                                2
#                          U6A                                 1
# deHAVILLAND              DHC-2                               2
# deHavilland              DHC-2                               3
# unknown                  Avid Flyer                          0
#                          kit                                 0
#                          unknown                             0
#
#                                                Weather.Condition  \
# Make                     Model
# 107.5 Flying Corporation One Design DR 107                     1
# 1200                     G103                                  1
# 177MF LLC                PITTS MODEL 12                        1
# 1977 COLFER-CHAN         STEEN SKYBOLT                         1
# 1ST FTR GP               FOCKE-WULF 190                        1
# 2000 McCoy               Genesis                               1
# 2001 MCGIRL              QUESTAIR VENTURE                      1
# 2003 Nash                Kitfox II                             1
# 2007 Savage Air LLC      EPIC LT                               1
# 3XTRIM                   450 ULTRA                             0
# 67 FLYING DUTCHMAN       D1/LFD-13                             1
# 781569 INC               FX 210                                1
# 85 MANISTA               KB-2                                  1
# A Pair of Jacks          RV-6A                                 1
# A. H. GETTINGS           GLASSAIR SH2                          1
# A. LE FRANCOIS           RANS S-7                              1
# A. Schleicher GMBH & Co. ASW 27-18                             1
# AAA Aircraft Leasing     192                                   1
# AARDEMA ROBERT JOHN      1 AARDEMA RAG WNG SP                  1
# AB SPORTINE AVIACIJA     GENESIS 2                             2
#                          LAK 17                                1
#                          LAK-17A                               1
# AB Sportine Aviacija     Genesis 2                             3
# ABBEY VICTOR             RV9-A                                 1
# ABBOTT                   GYROPLANE                             1
# ABC                      ABC 60 PLUS                           1
# ABERNATHY                LONG-EZ                               1
# ABRAMS/NUDING            QUICKIE Q2                            1
# AC Mfg & Dev't Co        CH 2000                               1
# ACKLAND JEFFREY DEAN     SH 3R                                 1
# ...                                                          ...
# de Havilland             DHC-7-102                             3
#                          DHC-7-103                             1
#                          DHC-8                                 4
#                          DHC-8-100                             1
#                          DHC-8-101                             2
#                          DHC-8-101/102                         1
#                          DHC-8-102                            10
#                          DHC-8-202                             2
#                          DHC-8-311                             3
#                          DHC-8-4002                            0
#                          DHC-94 Moth Minor                     1
#                          DHC-II                                1
#                          DHC2                                  2
#                          DHC2-MK I                             1
#                          DHC6-300                              1
#                          DHC6-33                               1
#                          DRAGONFLY DH-90                       1
#                          Dash 8-100                            1
#                          GIPSY MOTH DH.60G                     1
#                          OTTER DHC-3                           1
#                          SHD-6                                 2
#                          TIGER MOTH DH 82A                     2
#                          TIGER MOTH DH82A                      1
#                          U-6A                                  2
#                          U6A                                   1
# deHAVILLAND              DHC-2                                 2
# deHavilland              DHC-2                                 3
# unknown                  Avid Flyer                            1
#                          kit                                   1
#                          unknown                               1
#
#                                                Broad.Phase.of.Flight  \
# Make                     Model
# 107.5 Flying Corporation One Design DR 107                         0
# 1200                     G103                                      1
# 177MF LLC                PITTS MODEL 12                            1
# 1977 COLFER-CHAN         STEEN SKYBOLT                             1
# 1ST FTR GP               FOCKE-WULF 190                            1
# 2000 McCoy               Genesis                                   1
# 2001 MCGIRL              QUESTAIR VENTURE                          1
# 2003 Nash                Kitfox II                                 1
# 2007 Savage Air LLC      EPIC LT                                   1
# 3XTRIM                   450 ULTRA                                 0
# 67 FLYING DUTCHMAN       D1/LFD-13                                 1
# 781569 INC               FX 210                                    1
# 85 MANISTA               KB-2                                      1
# A Pair of Jacks          RV-6A                                     1
# A. H. GETTINGS           GLASSAIR SH2                              1
# A. LE FRANCOIS           RANS S-7                                  1
# A. Schleicher GMBH & Co. ASW 27-18                                 0
# AAA Aircraft Leasing     192                                       1
# AARDEMA ROBERT JOHN      1 AARDEMA RAG WNG SP                      1
# AB SPORTINE AVIACIJA     GENESIS 2                                 2
#                          LAK 17                                    1
#                          LAK-17A                                   1
# AB Sportine Aviacija     Genesis 2                                 2
# ABBEY VICTOR             RV9-A                                     1
# ABBOTT                   GYROPLANE                                 1
# ABC                      ABC 60 PLUS                               0
# ABERNATHY                LONG-EZ                                   1
# ABRAMS/NUDING            QUICKIE Q2                                1
# AC Mfg & Dev't Co        CH 2000                                   1
# ACKLAND JEFFREY DEAN     SH 3R                                     1
# ...                                                              ...
# de Havilland             DHC-7-102                                 3
#                          DHC-7-103                                 1
#                          DHC-8                                     4
#                          DHC-8-100                                 1
#                          DHC-8-101                                 2
#                          DHC-8-101/102                             1
#                          DHC-8-102                                10
#                          DHC-8-202                                 1
#                          DHC-8-311                                 3
#                          DHC-8-4002                                0
#                          DHC-94 Moth Minor                         1
#                          DHC-II                                    1
#                          DHC2                                      2
#                          DHC2-MK I                                 1
#                          DHC6-300                                  1
#                          DHC6-33                                   0
#                          DRAGONFLY DH-90                           1
#                          Dash 8-100                                1
#                          GIPSY MOTH DH.60G                         1
#                          OTTER DHC-3                               1
#                          SHD-6                                     2
#                          TIGER MOTH DH 82A                         2
#                          TIGER MOTH DH82A                          1
#                          U-6A                                      2
#                          U6A                                       0
# deHAVILLAND              DHC-2                                     2
# deHavilland              DHC-2                                     3
# unknown                  Avid Flyer                                1
#                          kit                                       1
#                          unknown                                   1
#
#                                                Report.Status  Publication.Date
# Make                     Model
# 107.5 Flying Corporation One Design DR 107                 1                 1
# 1200                     G103                              1                 1
# 177MF LLC                PITTS MODEL 12                    1                 1
# 1977 COLFER-CHAN         STEEN SKYBOLT                     1                 1
# 1ST FTR GP               FOCKE-WULF 190                    1                 1
# 2000 McCoy               Genesis                           1                 1
# 2001 MCGIRL              QUESTAIR VENTURE                  1                 1
# 2003 Nash                Kitfox II                         1                 1
# 2007 Savage Air LLC      EPIC LT                           1                 1
# 3XTRIM                   450 ULTRA                         1                 0
# 67 FLYING DUTCHMAN       D1/LFD-13                         1                 1
# 781569 INC               FX 210                            1                 1
# 85 MANISTA               KB-2                              1                 1
# A Pair of Jacks          RV-6A                             1                 1
# A. H. GETTINGS           GLASSAIR SH2                      1                 1
# A. LE FRANCOIS           RANS S-7                          1                 1
# A. Schleicher GMBH & Co. ASW 27-18                         1                 1
# AAA Aircraft Leasing     192                               1                 1
# AARDEMA ROBERT JOHN      1 AARDEMA RAG WNG SP              1                 1
# AB SPORTINE AVIACIJA     GENESIS 2                         2                 2
#                          LAK 17                            1                 1
#                          LAK-17A                           1                 1
# AB Sportine Aviacija     Genesis 2                         3                 3
# ABBEY VICTOR             RV9-A                             1                 1
# ABBOTT                   GYROPLANE                         1                 1
# ABC                      ABC 60 PLUS                       1                 1
# ABERNATHY                LONG-EZ                           1                 1
# ABRAMS/NUDING            QUICKIE Q2                        1                 1
# AC Mfg & Dev't Co        CH 2000                           1                 1
# ACKLAND JEFFREY DEAN     SH 3R                             1                 1
# ...                                                      ...               ...
# de Havilland             DHC-7-102                         3                 2
#                          DHC-7-103                         1                 0
#                          DHC-8                             4                 4
#                          DHC-8-100                         1                 1
#                          DHC-8-101                         2                 1
#                          DHC-8-101/102                     1                 1
#                          DHC-8-102                        10                10
#                          DHC-8-202                         2                 2
#                          DHC-8-311                         3                 3
#                          DHC-8-4002                        1                 1
#                          DHC-94 Moth Minor                 1                 1
#                          DHC-II                            1                 1
#                          DHC2                              2                 1
#                          DHC2-MK I                         1                 1
#                          DHC6-300                          1                 1
#                          DHC6-33                           1                 1
#                          DRAGONFLY DH-90                   1                 1
#                          Dash 8-100                        1                 1
#                          GIPSY MOTH DH.60G                 1                 1
#                          OTTER DHC-3                       1                 0
#                          SHD-6                             2                 2
#                          TIGER MOTH DH 82A                 2                 1
#                          TIGER MOTH DH82A                  1                 1
#                          U-6A                              2                 2
#                          U6A                               1                 1
# deHAVILLAND              DHC-2                             2                 2
# deHavilland              DHC-2                             3                 3
# unknown                  Avid Flyer                        1                 1
#                          kit                               1                 1
#                          unknown                           1                 1
#
# [19655 rows x 29 columns]

# %%
# Function that fixes the null in number.of.engines 
def fix_number_of_engines(noe, m):
    if noe >= 0:
        return noe
    else:
        # Setting number of engines at the mean number of engines for the producer
        r = np.round(df['Number.of.Engines'][df['Make']==m].mean())
        return r

# Setting 0 engines for balloons
df['Number.of.Engines'][df['Number.of.Engines'].isnull() & (df['Make'].str.contains('balloon', case=False))] = 0.0
# Correcting number of engines
num_engines = df.apply(lambda x: fix_number_of_engines(x['Number.of.Engines'], x['Make']), axis=1)
df = df.assign(NumberofEngines = num_engines, index=df.index)
# Still some null after number of engines correction
df['NumberofEngines'].fillna(1, inplace=True)

# %%
df=pd.DataFrame({"A":[14,4,5,4,1], 
                 "B":[5,2,54,3,2], 
                 "C":[20,20,7,3,8], 
                 "D":[14,3,6,2,6]}) 
df

# %%
def fix_engine_type(et, model):
    if type(et) == str:
        return et
    else:
        # Setting engine type at the mode of engines for the model
        e = (df['Engine.Type'][df['Model']==model].mode())
        return  e[0] if e.count() > 0 else 'Unknown'
# Fix for Engine.Type field      
en_type = df.apply(lambda x: fix_engine_type(x['Engine.Type'], x['Model']), axis=1)
df = df.assign(EngineType = en_type, index=df.index)

# %%
def fix_aircraft_category(cat, model):
    if type(cat) == str:
        return cat
    else:
        # Setting aircraft category at the mode of caterogories for the model
        e = (df['Aircraft.Category'][df['Model']==model].mode())
        return  e[0] if e.count() > 0 else 'Unknown'
# Fix for Aircraft.Category field      
aircraft_cat = df.apply(lambda x: fix_aircraft_category(x['Aircraft.Category'], x['Model']), axis=1)
df = df.assign(AircraftCategory = aircraft_cat, index=df.index)

# %%
# null damages can't be defined
df[df['Aircraft.Damage'].isnull()]
df['Aircraft.Damage'].fillna('Unknown', inplace=True)

# Fixing phase of flight nulls
df['Broad.Phase.of.Flight'].fillna('UNKNOWN', inplace=True)

# Fixing weather conditions
df['Weather.Condition'].fillna('UNK', inplace=True)

# null categories can't be defined
df['Aircraft.Category'].fillna('Unknown', inplace=True)

# can't define purpose of flight
df['Purpose.of.Flight'].fillna('Unknown', inplace=True)

# don't know ho to set missing schedules 
df['Schedule'].fillna('UNK', inplace=True)

# don't know ho to set missing FAR.Description
df['FAR.Description'].fillna('Unknown', inplace=True)

# don't know ho to set missing Aircraft.Damage
df['Aircraft.Damage'].fillna('Unknown', inplace=True)

# don't know ho to set missing Air Carriers
df['Air.Carrier'].fillna('Unknown', inplace=True)

# don't know ho to set missing Makers
df['Make'].fillna('UNKNOWN', inplace=True)

# don't know ho to set missing Models
df['Model'].fillna('Unknown', inplace=True)

# don't know ho to set missing airport names
df['Airport.Name'].fillna('Unknown', inplace=True)

# don't know ho to set missing Models
df['Airport.Code'].fillna('Unknown', inplace=True)

# don't know ho to set missing Locations
df['Location'].fillna('Unknown', inplace=True)

# %%
# How many still null
df.isnull().sum()
# Out:
# Event.Id                      0
# Investigation.Type            1
# Accident.Number               0
# Event.Date                    0
# Location                      0
# Country                     507
# Latitude                  53903
# Longitude                 53912
# Airport.Code                  0
# Airport.Name                  0
# Injury.Severity               0
# Aircraft.Damage               0
# Aircraft.Category             0
# Registration.Number        3582
# Make                          0
# Model                         0
# Amateur.Built               627
# Number.of.Engines          4609
# Engine.Type                3982
# FAR.Description               0
# Schedule                      0
# Purpose.of.Flight             0
# Air.Carrier                   0
# Total.Fatal.Injuries      25967
# Total.Serious.Injuries    28466
# Total.Minor.Injuries      27288
# Total.Uninjured           13795
# Weather.Condition             0
# Broad.Phase.of.Flight         0
# Report.Status                 0
# Publication.Date          14014
# dtype: int64

# %% [markdown]
# ## More Resources
#
# Learn how to make the most of Python, Jupyter, Colaboratory, and related tools with these resources:
#
# ### Working with Notebooks in Colaboratory
# - [Overview of Colaboratory](/notebooks/basic_features_overview.ipynb)
# - [Guide to Markdown](/notebooks/markdown_guide.ipynb)
# - [Importing libraries and installing dependencies](/notebooks/snippets/importing_libraries.ipynb)
# - [Saving and loading notebooks in GitHub](https://colab.research.google.com/github/googlecolab/colabtools/blob/master/notebooks/colab-github-demo.ipynb)
# - [Interactive forms](/notebooks/forms.ipynb)
# - [Interactive widgets](/notebooks/widgets.ipynb)
#
# ### Working with Data
# - [Loading data: Drive, Sheets, and Google Cloud Storage](/notebooks/io.ipynb)
# - [Charts: visualizing data](/notebooks/charts.ipynb)
# - [Getting started with BigQuery](/notebooks/bigquery.ipynb)
#
# ### Machine Learning Crash Course
# These are a few of the notebooks from Google's online Machine Learning course. See the [full course website](https://developers.google.com/machine-learning/crash-course/) for more.
# - [Intro to Pandas](/notebooks/mlcc/intro_to_pandas.ipynb)
# - [Tensorflow concepts](/notebooks/mlcc/tensorflow_programming_concepts.ipynb)
# - [First steps with TensorFlow](/notebooks/mlcc/first_steps_with_tensor_flow.ipynb)
# - [Intro to neural nets](/notebooks/mlcc/intro_to_neural_nets.ipynb)
# - [Intro to sparse data and embeddings](/notebooks/mlcc/intro_to_sparse_data_and_embeddings.ipynb)
#
# ### Using Accelerated Hardware
# - [TensorFlow with GPUs](/notebooks/gpu.ipynb)
# - [TensorFlow with TPUs](/notebooks/tpu.ipynb)

# %% [markdown]
# ## Machine Learning Examples: Seedbank
#
# To see end-to-end examples of the interactive machine learning analyses that Colaboratory makes possible, check out the [Seedbank](https://research.google.com/seedbank/) project.
#
# A few featured examples:
#
# - [Neural Style Transfer](https://research.google.com/seedbank/seed/neural_style_transfer_with_tfkeras): Use deep learning to transfer style between images.
# - [EZ NSynth](https://research.google.com/seedbank/seed/ez_nsynth): Synthesize audio with WaveNet auto-encoders.
# - [Fashion MNIST with Keras and TPUs](https://research.google.com/seedbank/seed/fashion_mnist_with_keras_and_tpus): Classify fashion-related images with deep learning.
# - [DeepDream](https://research.google.com/seedbank/seed/deepdream): Produce DeepDream images from your own photos.
# - [Convolutional VAE](https://research.google.com/seedbank/seed/convolutional_vae): Create a generative model of handwritten digits.
